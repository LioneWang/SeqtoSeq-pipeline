# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Part1 数据预处理

# %%
#根据自己的路径进行修改
# %cd /content/drive/MyDrive/workspace/RNN/
# Out:
# /content/drive/MyDrive/workspace/RNN

# %%
# 读取当前路径下的数据文件
import jieba
import pandas as pd
data = pd.read_csv('news-commentary-v14.en-zh.tsv',sep="\t", on_bad_lines='skip')
# Out:
# /usr/local/lib/python3.12/dist-packages/jieba/__init__.py:44: SyntaxWarning: invalid escape sequence '\.'
#   re_han_default = re.compile("([\u4E00-\u9FD5a-zA-Z0-9+#&\._%\-]+)", re.U)
# /usr/local/lib/python3.12/dist-packages/jieba/__init__.py:46: SyntaxWarning: invalid escape sequence '\s'
#   re_skip_default = re.compile("(\r\n|\s)", re.U)
# /usr/local/lib/python3.12/dist-packages/jieba/finalseg/__init__.py:78: SyntaxWarning: invalid escape sequence '\.'
#   re_skip = re.compile("([a-zA-Z0-9]+(?:\.\d+)?%?)")

# %%
data.head()
# Out:
#                                        1929 or 1989?  \
# 0  PARIS – As the economic crisis deepens and wid...
# 1  At the start of the crisis, many people likene...
# 2  Today, the mood is much grimmer, with referenc...
# 3  The tendency is either excessive restraint (Eu...
# 4  Europe is being cautious in the name of avoidi...
#
#                                        1929年还是1989年?
# 0  巴黎-随着经济危机不断加深和蔓延，整个世界一直在寻找历史上的类似事件希望有助于我们了解目前正...
# 1  一开始，很多人把这次危机比作1982年或1973年所发生的情况，这样得类比是令人宽心的，因为...
# 2  如今人们的心情却是沉重多了，许多人开始把这次危机与1929年和1931年相比，即使一些国家政...
# 3             目前的趋势是，要么是过度的克制（欧洲 ） ， 要么是努力的扩展（美国 ） 。
# 4  欧洲在避免债务和捍卫欧元的名义下正变得谨慎，而美国已经在许多方面行动起来，以利用这一理想的时...

# %%
example_sent = data.iloc[2, 1]
print(example_sent)
# Out:
# 如今人们的心情却是沉重多了，许多人开始把这次危机与1929年和1931年相比，即使一些国家政府的表现仍然似乎把视目前的情况为是典型的而看见的衰退。

# %%
" ".join(jieba.cut(example_sent, HMM=True))
# Out:
# Building prefix dict from the default dictionary ...
# DEBUG:jieba:Building prefix dict from the default dictionary ...
# Dumping model to file cache /tmp/jieba.cache
# DEBUG:jieba:Dumping model to file cache /tmp/jieba.cache
# Loading model cost 0.668 seconds.
# DEBUG:jieba:Loading model cost 0.668 seconds.
# Prefix dict has been built successfully.
# DEBUG:jieba:Prefix dict has been built successfully.
# '如今 人们 的 心情 却是 沉重 多 了 ， 许多 人 开始 把 这次 危机 与 1929 年 和 1931 年 相比 ， 即使 一些 国家 政府 的 表现 仍然 似乎 把视 目前 的 情况 为 是 典型 的 而 看见 的 衰退 。'

# %%
" ".join(jieba.cut(example_sent, HMM=False))
# Out:
# '如今 人们 的 心情 却是 沉重 多 了 ， 许多 人 开始 把 这次 危机 与 1929 年 和 1931 年 相比 ， 即使 一些 国家 政府 的 表现 仍然 似乎 把 视 目前 的 情况 为 是 典型 的 而 看见 的 衰退 。'

# %%
count = 0
def func(y):
    global count
    count += 1
    if count % 10000 == 0:
        print(count)
    return " ".join(jieba.cut(str(y), HMM=True))

# %%
#func = (lambda x: " ".join(jieba.cut(x.iloc[1], HMM=True)))
import tqdm
data.iloc[:, 1] = data.iloc[:, 1].apply(func)
# Out:
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300000

# %%
data.dropna()
# Out:
#                                             1929 or 1989?  \
# 0       PARIS – As the economic crisis deepens and wid...
# 1       At the start of the crisis, many people likene...
# 2       Today, the mood is much grimmer, with referenc...
# 3       The tendency is either excessive restraint (Eu...
# 4       Europe is being cautious in the name of avoidi...
# ...                                                   ...
# 306133  Their achievement remains one of the greatest ...
# 306134  At the same time, Zuma’s revolutionary generat...
# 306135  In a region that reveres the elderly, Zuma’s a...
# 306136  Three in ten South Africans are younger than 1...
# 306137  Somehow Zuma must find a way to honor his own ...
#
#                                             1929年还是1989年?
# 0       巴黎 - 随着 经济危机 不断 加深 和 蔓延 ， 整个 世界 一直 在 寻找 历史 上 的...
# 1       一 开始 ， 很多 人 把 这次 危机 比作 1982 年 或 1973 年 所 发生 的 ...
# 2       如今 人们 的 心情 却是 沉重 多 了 ， 许多 人 开始 把 这次 危机 与 1929 ...
# 3       目前 的 趋势 是 ， 要么 是 过度 的 克制 （ 欧洲   ）   ，   要么 是 努...
# 4       欧洲 在 避免 债务 和 捍卫 欧元 的 名义 下正 变得 谨慎 ， 而 美国 已经 在 许...
# ...                                                   ...
# 306133              这 一代人 的 成就 是 现代 � � 史上 最 伟大 的 成就 之一 。
# 306134  同时 ， 祖马 革命 的 一代 似乎 对 领导 打破 种族隔离 制度 15 年 后 的 南非...
# 306135  在 一个 尊敬 老人 的 地区 ， 祖马 对 其 乡下 传统 的 依恋 ， 必须 和 对 南...
# 306136  在 南非 ， 每 10 个人 中 就 有 三个 人 的 年龄 小于 15 岁 ， 这 意味着...
# 306137  在 某种程度 上 ， 祖马 在 给予 那些 心灵 每天 都 会 被 阶层 差异 刺痛 以及 ...
#
# [298108 rows x 2 columns]

# %%
list_en = list(data.iloc[:, 0])
list_zh = list(data.iloc[:, 1])

# %%
len(list_en)
# Out:
# 306139

# %%
len(list_zh)
# Out:
# 306139

# %%
# split data to train,valid and test
import random
all_indexes = set([i for i in range(110380)])
indexes = list(set(random.choices([i for i in range(110380)], k=20000)))
test_indexes = set(indexes[:10000])
dev_indexes = set(indexes[10000:])
train_indexes = all_indexes - test_indexes - dev_indexes

# %%
len(all_indexes), len(test_indexes), len(dev_indexes), len(train_indexes)
# Out:
# (110380, 10000, 8292, 92088)

# %%
sum([len(test_indexes), len(dev_indexes), len(train_indexes)])
# Out:
# 110380

# %%
def save_dataset(name_en, name_zh, indexes, list_en, list_zh):
    res_en, res_zh = "", ""
    count = 0
    c2 = 0

    for index in indexes:
        try:
            c2 += 1
            res_en += list_en[index] + "\n"
            res_zh += list_zh[index] + "\n"
        except:
            count += 1
    print(count, c2)

    open(name_en, "w").write(res_en)
    open(name_zh, "w").write(res_zh)

# %%
save_dataset("dev.en", "dev.zh", dev_indexes, list_en, list_zh)
save_dataset("test.en", "test.zh", test_indexes, list_en, list_zh)
save_dataset("train.en", "train.zh", train_indexes, list_en, list_zh)
# Out:
# 231 8292
# 239 10000
# 2416 92088

# %%
# !zip data.zip *.en *.zh
# Out:
#   adding: dev.en (deflated 62%)
#   adding: test.en (deflated 62%)
#   adding: train.en (deflated 63%)
#   adding: dev.zh (deflated 59%)
#   adding: test.zh (deflated 59%)
#   adding: train.zh (deflated 61%)

# %% [markdown]
# # Part2 创建词嵌入的映射

# %%
# !pip install -r gpu_requirements.txt > _
# !pip install git+https://github.com/d2l-ai/d2l-zh@release > _ # installing d2l
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires tqdm>=4.64.1, but you have tqdm 4.29.1 which is incompatible.
# spacy 3.8.8 requires tqdm<5.0.0,>=4.38.0, but you have tqdm 4.29.1 which is incompatible.
# prophet 1.1.7 requires tqdm>=4.36.1, but you have tqdm 4.29.1 which is incompatible.
# datasets 4.0.0 requires tqdm>=4.66.3, but you have tqdm 4.29.1 which is incompatible.
# huggingface-hub 0.36.0 requires tqdm>=4.42.1, but you have tqdm 4.29.1 which is incompatible.
# dataproc-spark-connect 0.8.3 requires tqdm>=4.67, but you have tqdm 4.29.1 which is incompatible.
#   Running command git clone --filter=blob:none --quiet https://github.com/d2l-ai/d2l-zh /tmp/pip-req-build-y0n60lm1
#   Running command git checkout -b release --track origin/release
#   Switched to a new branch 'release'
#   Branch 'release' set up to track remote branch 'release' from 'origin'.
#   Running command git submodule update --init --recursive -q
# ERROR: Ignored the following versions that require a different python version: 1.21.2 Requires-Python >=3.7,<3.11; 1.21.3 Requires-Python >=3.7,<3.11; 1.21.4 Requires-Python >=3.7,<3.11; 1.21.5 Requires-Python >=3.7,<3.11; 1.21.6 Requires-Python >=3.7,<3.11
# ERROR: Could not find a version that satisfies the requirement numpy==1.21.5 (from d2l) (from versions: 1.3.0, 1.4.1, 1.5.0, 1.5.1, 1.6.0, 1.6.1, 1.6.2, 1.7.0, 1.7.1, 1.7.2, 1.8.0, 1.8.1, 1.8.2, 1.9.0, 1.9.1, 1.9.2, 1.9.3, 1.10.0.post2, 1.10.1, 1.10.2, 1.10.4, 1.11.0, 1.11.1, 1.11.2, 1.11.3, 1.12.0, 1.12.1, 1.13.0, 1.13.1, 1.13.3, 1.14.0, 1.14.1, 1.14.2, 1.14.3, 1.14.4, 1.14.5, 1.14.6, 1.15.0, 1.15.1, 1.15.2, 1.15.3, 1.15.4, 1.16.0, 1.16.1, 1.16.2, 1.16.3, 1.16.4, 1.16.5, 1.16.6, 1.17.0, 1.17.1, 1.17.2, 1.17.3, 1.17.4, 1.17.5, 1.18.0, 1.18.1, 1.18.2, 1.18.3, 1.18.4, 1.18.5, 1.19.0, 1.19.1, 1.19.2, 1.19.3, 1.19.4, 1.19.5, 1.20.0, 1.20.1, 1.20.2, 1.20.3, 1.21.0, 1.21.1, 1.22.0, 1.22.1, 1.22.2, 1.22.3, 1.22.4, 1.23.0, 1.23.1, 1.23.2, 1.23.3, 1.23.4, 1.23.5, 1.24.0, 1.24.1, 1.24.2, 1.24.3, 1.24.4, 1.25.0, 1.25.1, 1.25.2, 1.26.0, 1.26.1, 1.26.2, 1.26.3, 1.26.4, 2.0.0, 2.0.1, 2.0.2, 2.1.0, 2.1.1, 2.1.2, 2.1.3, 2.2.0, 2.2.1, 2.2.2, 2.2.3, 2.2.4, 2.2.5, 2.2.6, 2.3.0, 2.3.1, 2.3.2, 2.3.3, 2.3.4, 2.3.5)
# ERROR: No matching distribution found for numpy==1.21.5

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import math

import numpy as np
import nltk
import sentencepiece as spm
import jieba

nltk.download('punkt')


def pad_sents(sents, pad_token):
    """ Pad list of sentences according to the longest sentence in the batch.
        The paddings should be at the end of each sentence.
    @param sents (list[list[str]]): list of sentences, where each sentence
                                    is represented as a list of words
    @param pad_token (str): padding token
    @returns sents_padded (list[list[str]]): list of sentences where sentences shorter
        than the max length sentence are padded out with the pad_token, such that
        each sentences in the batch now has equal length.
    """
    sents_padded = []

    ### YOUR CODE HERE (~6 Lines)
    max_len = max([len(each) for each in sents])
    for sent in sents:
        sent += [pad_token] * (max_len - len(sent))
        sents_padded.append(sent)

    ### END YOUR CODE

    return sents_padded


def read_corpus(file_path, source, vocab_size=2500):
    """ Read file, where each sentence is dilineated by a `\n`.
    @param file_path (str): path to file containing corpus
    @param source (str): "tgt" or "src" indicating whether text
        is of the source language or target language
    @param vocab_size (int): number of unique subwords in
        vocabulary when reading and tokenizing
    """
    data = []
    sp = spm.SentencePieceProcessor()
    sp.load('{}.model'.format(source))

    with open(file_path, 'r', encoding='utf8') as f:
        for line in f:
            subword_tokens = sp.encode_as_pieces(line)

            # only append <s> and </s> to the target sentence
            if source == 'tgt':
                subword_tokens = ["<s>"] + subword_tokens + ["</s>"]

            data.append(subword_tokens)

    return data


def read_sent_zh(sent, source):
    """ Read a Chinese sentence, seperate the words using jieba, and generate tokens
    @param sent (str): path to file containing corpus
    @param source (str): "tgt" or "src" for selecting sp model
    """
    sp = spm.SentencePieceProcessor()
    sp.load('{}.model'.format(source))

    sent = " ".join(jieba.cut(sent, HMM=True))
    subword_tokens = sp.encode_as_pieces(sent)

    return subword_tokens


def batch_iter(data, batch_size, shuffle=False):
    """ Yield batches of source and target sentences reverse sorted by length (largest to smallest).
    @param data (list of (src_sent, tgt_sent)): list of tuples containing source and target sentence
    @param batch_size (int): batch size
    @param shuffle (boolean): whether to randomly shuffle the dataset
    """
    batch_num = math.ceil(len(data) / batch_size)
    index_array = list(range(len(data)))

    if shuffle:
        np.random.shuffle(index_array)

    for i in range(batch_num):
        indices = index_array[i * batch_size: (i + 1) * batch_size]
        examples = [data[idx] for idx in indices]

        examples = sorted(examples, key=lambda e: len(e[0]), reverse=True)
        examples = [examples[i] for i in range(len(examples)) if len(examples[i][0]) > 0 and len(examples[i][1]) > 0]

        src_sents = [e[0] for e in examples]
        tgt_sents = [e[1] for e in examples]
        yield src_sents, tgt_sents
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-


from collections import Counter
from itertools import chain
import json
import torch
from typing import List
import sentencepiece as spm
import os

class VocabEntry(object):
    """ Vocabulary Entry, i.e. structure containing either
    src or tgt language terms.
    """
    def __init__(self, word2id=None):
        """ Init VocabEntry Instance.
        @param word2id (dict): dictionary mapping words 2 indices
        """
        if word2id:
            self.word2id = word2id
        else:
            self.word2id = dict()
            self.word2id['<pad>'] = 0   # Pad Token
            self.word2id['<s>'] = 1     # Start Token
            self.word2id['</s>'] = 2    # End Token
            self.word2id['<unk>'] = 3   # Unknown Token
        self.unk_id = self.word2id['<unk>']
        self.id2word = {v: k for k, v in self.word2id.items()}

    def __getitem__(self, word):
        """ Retrieve word's index. Return the index for the unk
        token if the word is out of vocabulary.
        @param word (str): word to look up.
        @returns index (int): index of word
        """
        return self.word2id.get(word, self.unk_id)

    def __contains__(self, word):
        """ Check if word is captured by VocabEntry.
        @param word (str): word to look up
        @returns contains (bool): whether word is contained
        """
        return word in self.word2id

    def __len__(self):
        """ Compute number of words in VocabEntry.
        @returns len (int): number of words in VocabEntry
        """
        return len(self.word2id)

    def __repr__(self):
        """ Representation of VocabEntry to be used
        when printing the object.
        """
        return 'Vocabulary[size=%d]' % len(self)


    def get_word_from_id(self, wid):
        """ Return mapping of index to word.
        @param wid (int): word index
        @returns word (str): word corresponding to index
        """
        return self.id2word[wid]

    def add(self, word):
        """ Add word to VocabEntry, if it is previously unseen.
        @param word (str): word to add to VocabEntry
        @return index (int): index that the word has been assigned
        """
        if word not in self:
            wid = self.word2id[word] = len(self)
            self.id2word[wid] = word
            return wid
        else:
            return self[word]

    def words2indices(self, sents):
        """ Convert list of words or list of sentences of words
        into list or list of list of indices.
        @param sents (list[str] or list[list[str]]): sentence(s) in words
        @return word_ids (list[int] or list[list[int]]): sentence(s) in indices
        """
        if type(sents[0]) == list:
            return [[self[w] for w in s] for s in sents]
        else:
            return [self[w] for w in sents]

    def indices2words(self, word_ids):
        """ Convert list of indices into words.
        @param word_ids (list[int]): list of word ids
        @return sents (list[str]): list of words
        """
        return [self.id2word[w_id] for w_id in word_ids]

    def to_input_tensor(self, sents: List[List[str]], device: torch.device) -> torch.Tensor:
        """ Convert list of sentences (words) into tensor with necessary padding for
        shorter sentences.

        @param sents (List[List[str]]): list of sentences (words)
        @param device: device on which to load the tesnor, i.e. CPU or GPU

        @returns sents_var: tensor of (max_sentence_length, batch_size)
        """
        word_ids = self.words2indices(sents)
        # 假设 pad_sents 存在于 utils.py
        try:
            sents_t = pad_sents(word_ids, self['<pad>'])
            sents_var = torch.tensor(sents_t, dtype=torch.long, device=device)
            return torch.t(sents_var)
        except NameError:
            print("Warning: 'pad_sents' not found. Skipping tensor conversion.")
            return None


    @staticmethod
    def from_corpus(corpus, size, freq_cutoff=2):
        """ Given a corpus construct a Vocab Entry.
        @param corpus (list[str]): corpus of text produced by read_corpus function
        @param size (int): # of words in vocabulary
        @param freq_cutoff (int): if word occurs n < freq_cutoff times, drop the word
        @returns vocab_entry (VocabEntry): VocabEntry instance produced from provided corpus
        """
        vocab_entry = VocabEntry()
        word_freq = Counter(chain(*corpus))
        valid_words = [w for w, v in word_freq.items() if v >= freq_cutoff]
        print('number of word types: {}, number of word types w/ frequency >= {}: {}'
              .format(len(word_freq), freq_cutoff, len(valid_words)))
        top_k_words = sorted(valid_words, key=lambda w: word_freq[w], reverse=True)[:size]
        for word in top_k_words:
            vocab_entry.add(word)
        return vocab_entry

    @staticmethod
    def from_subword_list(subword_list):
        vocab_entry = VocabEntry()
        # 添加特殊的 tokens，确保它们在 subword list 之前
        # （注意：原始的 from_subword_list 没有这个，但它可能会导致
        #  <pad> 等 token 被后来的 subword 覆盖索引 0-3）
        # 修正：VocabEntry 的 __init__ 已经处理了 0-3，所以这里是安全的。
        for subword in subword_list:
            vocab_entry.add(subword)
        return vocab_entry


class Vocab(object):
    """ Vocab encapsulating src and target langauges.
    """
    def __init__(self, src_vocab: VocabEntry, tgt_vocab: VocabEntry):
        """ Init Vocab.
        @param src_vocab (VocabEntry): VocabEntry for source language
        @param tgt_vocab (VocabEntry): VocabEntry for target language
        """
        self.src = src_vocab
        self.tgt = tgt_vocab

    @staticmethod
    def build(src_sents, tgt_sents) -> 'Vocab':
        """ Build Vocabulary.
        @param src_sents (list[str]): Source subwords provided by SentencePiece
        @param tgt_sents (list[str]): Target subwords provided by SentencePiece
        """

        print('initialize source vocabulary ..')
        src = VocabEntry.from_subword_list(src_sents)

        print('initialize target vocabulary ..')
        tgt = VocabEntry.from_subword_list(tgt_sents)

        return Vocab(src, tgt)

    def save(self, file_path):
        """ Save Vocab to file as JSON dump.
        @param file_path (str): file path to vocab file
        """
        print(f'Saving vocabulary to {file_path}...')
        with open(file_path, 'w', encoding='utf-8') as f:
            json.dump(dict(src_word2id=self.src.word2id, tgt_word2id=self.tgt.word2id), f, indent=2, ensure_ascii=False)

    @staticmethod
    def load(file_path):
        """ Load vocabulary from JSON dump.
        @param file_path (str): file path to vocab file
        @returns Vocab object loaded from JSON dump
        """
        print(f'Loading vocabulary from {file_path}...')
        with open(file_path, 'r', encoding='utf-8') as f:
            entry = json.load(f)
        src_word2id = entry['src_word2id']
        tgt_word2id = entry['tgt_word2id']
        return Vocab(VocabEntry(src_word2id), VocabEntry(tgt_word2id))

    def __repr__(self):
        """ Representation of Vocab to be used
        when printing the object.
        """
        return 'Vocab(source %d words, target %d words)' % (len(self.src), len(self.tgt))


def get_vocab_list(file_path, source, vocab_size):
    """ Use SentencePiece to tokenize and acquire list of unique subwords.
    @param file_path (str): file path to corpus
    @param source (str): 'tgt' or 'src' (used for model prefix)
    @param vocab_size: desired vocabulary size
    """
    print(f"Training SentencePiece model for '{source}' from file '{file_path}'...")
    # 定义模型前缀
    model_prefix = f'{source}'

    # 训练 spm 模型
    # 我们添加 --model_type=bpe 和一些控制参数

    # 为中文和英文分别训练一个分词模型
    spm.SentencePieceTrainer.train(
        input=file_path,
        model_prefix=model_prefix,
        vocab_size=vocab_size,
        model_type='bpe'
    )

    # 创建一个实例
    sp = spm.SentencePieceProcessor()
    # 加载 .model 文件
    sp.load(f'{model_prefix}.model')

    # 获取 subword 列表
    sp_list = [sp.id_to_piece(piece_id) for piece_id in range(sp.get_piece_size())]

    print(f"Finished training for '{source}'. Vocab size: {len(sp_list)}")

    return sp_list


# --- 新的执行函数 ---
def run_vocab_builder(train_src_file, train_tgt_file, vocab_output_file, src_vocab_size, tgt_vocab_size):
    """
    执行词汇表构建的主逻辑。
    """
    print('read in source sentences: %s' % train_src_file)
    print('read in target sentences: %s' % train_tgt_file)

    src_sents = get_vocab_list(train_src_file, source='src', vocab_size=src_vocab_size)
    tgt_sents = get_vocab_list(train_tgt_file, source='tgt', vocab_size=tgt_vocab_size)

    vocab = Vocab.build(src_sents, tgt_sents)
    print('generated vocabulary, source %d words, target %d words' % (len(src_sents), len(tgt_sents)))

    vocab.save(vocab_output_file)
    print('vocabulary saved to %s' % vocab_output_file)

# %%
# parameters to tune
PARAM_TRAIN_SRC = 'train.zh'
PARAM_TRAIN_TGT = 'train.en'

# 输出文件
PARAM_VOCAB_FILE = 'vocab_zh_en.json'

# 词汇表大小（在原始脚本中是硬编码的）
PARAM_SRC_VOCAB_SIZE = 21000
PARAM_TGT_VOCAB_SIZE = 8000

# %%
# 生成映射之后的中文和英文单词
run_vocab_builder(
            train_src_file=PARAM_TRAIN_SRC,
            train_tgt_file=PARAM_TRAIN_TGT,
            vocab_output_file=PARAM_VOCAB_FILE,
            src_vocab_size=PARAM_SRC_VOCAB_SIZE,
            tgt_vocab_size=PARAM_TGT_VOCAB_SIZE
        )
# Out:
# read in source sentences: train.zh
# read in target sentences: train.en
# Training SentencePiece model for 'src' from file 'train.zh'...
# Finished training for 'src'. Vocab size: 21000
# Training SentencePiece model for 'tgt' from file 'train.en'...
# Finished training for 'tgt'. Vocab size: 8000
# initialize source vocabulary ..
# initialize target vocabulary ..
# generated vocabulary, source 21000 words, target 8000 words
# Saving vocabulary to vocab_zh_en.json...
# vocabulary saved to vocab_zh_en.json

# %% [markdown]
# # Part3:训练和验证

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import sys
from collections import namedtuple
from typing import Dict, List, Set, Tuple, Union

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.nn.utils
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence


Hypothesis = namedtuple('Hypothesis', ['value', 'score'])


class ModelEmbeddings(nn.Module):
    """
    Class that converts input words to their embeddings.
    """
    def __init__(self, embed_size, vocab):
        """
        Init the Embedding layers.

        @param embed_size (int): Embedding size (dimensionality)
        @param vocab (Vocab): Vocabulary object containing src and tgt languages
                              See vocab.py for documentation.
        """
        super(ModelEmbeddings, self).__init__()
        self.embed_size = embed_size

        # default values
        self.source = None
        self.target = None

        src_pad_token_idx = vocab.src['<pad>']
        tgt_pad_token_idx = vocab.tgt['<pad>']

        self.source = nn.Embedding(len(vocab.src), self.embed_size, padding_idx = src_pad_token_idx)
        self.target = nn.Embedding(len(vocab.tgt), self.embed_size, padding_idx = tgt_pad_token_idx)


class NMT(nn.Module):
    """ Simple Neural Machine Translation Model:
        - RNN Encoder
        - Unidirection LSTM Decoder
        - Global Attention Model (Luong, et al. 2015)
    """
    def __init__(self, embed_size, hidden_size, vocab, dropout_rate=0.2, rnn_layer=nn.LSTM, num_layers=1, activation=torch.tanh,bidirectional=False):
        """ Init NMT Model.

        @param embed_size (int): Embedding size (dimensionality)
        @param hidden_size (int): Hidden Size, the size of hidden states (dimensionality)
        @param vocab (Vocab): Vocabulary object containing src and tgt languages
                              See vocab.py for documentation.
        @param dropout_rate (float): Dropout probability, for attention
        """
        super(NMT, self).__init__()
        self.model_embeddings = ModelEmbeddings(embed_size, vocab)
        self.hidden_size = hidden_size
        self.dropout_rate = dropout_rate
        self.vocab = vocab
        self.rnn_layer = rnn_layer
        self.num_layers = num_layers
        self.activation = activation

        # default values
        self.encoder = None
        self.decoder = None
        self.h_projection = None
        self.c_projection = None
        self.att_projection = None
        self.combined_output_projection = None
        self.target_vocab_projection = None
        self.dropout = None

        # model layers
        self.is_lstm = (rnn_layer == nn.LSTM)
        self.encoder = rnn_layer(input_size=embed_size, hidden_size=hidden_size, bidirectional=bidirectional, bias=True, num_layers=num_layers)
        self.decoder = nn.LSTMCell(input_size=embed_size+hidden_size, hidden_size=hidden_size, bias=True)
        self.h_projection = nn.Linear(hidden_size*2, hidden_size, bias=False)
        if self.is_lstm:
            self.c_projection = nn.Linear(hidden_size*2, hidden_size, bias=False)
        self.att_projection = nn.Linear(hidden_size*2, hidden_size, bias=False)
        self.combined_output_projection = nn.Linear(hidden_size*3, hidden_size, bias=False)
        self.target_vocab_projection = nn.Linear(hidden_size, len(vocab.tgt), bias=False)
        self.dropout = nn.Dropout(p=self.dropout_rate)


    def forward(self, source: List[List[str]], target: List[List[str]]) -> torch.Tensor:
        """ Take a mini-batch of source and target sentences, compute the log-likelihood of
        target sentences under the language models learned by the NMT system.

        @param source (List[List[str]]): list of source sentence tokens
        @param target (List[List[str]]): list of target sentence tokens, wrapped by `<s>` and `</s>`

        @returns scores (Tensor): a variable/tensor of shape (b, ) representing the
                                    log-likelihood of generating the gold-standard target sentence for
                                    each example in the input batch. Here b = batch size.
        """
        # Compute sentence lengths
        source_lengths = [len(s) for s in source]

        # Convert list of lists into tensors
        source_padded = self.vocab.src.to_input_tensor(source, device=self.device)   # Tensor: (src_len, b)
        target_padded = self.vocab.tgt.to_input_tensor(target, device=self.device)   # Tensor: (tgt_len, b)

        enc_hiddens, dec_init_state = self.encode(source_padded, source_lengths)
        enc_masks = self.generate_sent_masks(enc_hiddens, source_lengths)
        combined_outputs = self.decode(enc_hiddens, enc_masks, dec_init_state, target_padded)
        P = F.log_softmax(self.target_vocab_projection(combined_outputs), dim=-1)

        # Zero out, probabilities for which we have nothing in the target text
        target_masks = (target_padded != self.vocab.tgt['<pad>']).float()

        # Compute log probability of generating true target words
        target_gold_words_log_prob = torch.gather(P, index=target_padded[1:].unsqueeze(-1), dim=-1).squeeze(-1) * target_masks[1:]
        scores = target_gold_words_log_prob.sum(dim=0)
        return scores


    def encode(self, source_padded: torch.Tensor, source_lengths: List[int]) -> Tuple[torch.Tensor, Tuple[torch.Tensor, torch.Tensor]]:
        """ Apply the encoder to source sentences to obtain encoder hidden states.
            Additionally, take the final states of the encoder and project them to obtain initial states for decoder.

        @param source_padded (Tensor): Tensor of padded source sentences with shape (src_len, b), where
                                        b = batch_size, src_len = maximum source sentence length. Note that
                                       these have already been sorted in order of longest to shortest sentence.
        @param source_lengths (List[int]): List of actual lengths for each of the source sentences in the batch
        @returns enc_hiddens (Tensor): Tensor of hidden units with shape (b, src_len, h*2), where
                                        b = batch size, src_len = maximum source sentence length, h = hidden size.
        @returns dec_init_state (tuple(Tensor, Tensor)): Tuple of tensors representing the decoder's initial
                                                hidden state and cell.
        """
        enc_hiddens, dec_init_state = None, None
        last_hidden, last_cell = None, None
        X = self.model_embeddings.source(source_padded) # (src_len, b, e)
        enc_hiddens, last_state = self.encoder(pack_padded_sequence(X, source_lengths))
        if self.is_lstm:
            last_hidden, last_cell = last_state
        else:
            last_hidden = last_state
        enc_hiddens, _ = pad_packed_sequence(enc_hiddens) # returns seq_unpacked, lens_unpacked
        enc_hiddens = enc_hiddens.permute(1, 0, 2)

        init_decoder_hidden = self.h_projection(torch.cat((last_hidden[-2], last_hidden[-1]), 1))

        if self.is_lstm:
            # (b, 2*h)
            init_decoder_cell = self.c_projection(torch.cat((last_cell[-2], last_cell[-1]), 1))
            dec_init_state = (init_decoder_hidden, init_decoder_cell)
        else:
            dec_init_state = (init_decoder_hidden, torch.zeros_like(init_decoder_hidden))

        print(enc_hiddens.shape)
        print("*"*40)
        return enc_hiddens, dec_init_state


    def decode(self, enc_hiddens: torch.Tensor, enc_masks: torch.Tensor,
                dec_init_state: Tuple[torch.Tensor, torch.Tensor], target_padded: torch.Tensor) -> torch.Tensor:
        """Compute combined output vectors for a batch.

        @param enc_hiddens (Tensor): Hidden states (b, src_len, h*2), where
                                     b = batch size, src_len = maximum source sentence length, h = hidden size.
        @param enc_masks (Tensor): Tensor of sentence masks (b, src_len), where
                                     b = batch size, src_len = maximum source sentence length.
        @param dec_init_state (tuple(Tensor, Tensor)): Initial state and cell for decoder
        @param target_padded (Tensor): Gold-standard padded target sentences (tgt_len, b), where
                                       tgt_len = maximum target sentence length, b = batch size.

        @returns combined_outputs (Tensor): combined output tensor  (tgt_len, b,  h), where
                                        tgt_len = maximum target sentence length, b = batch_size,  h = hidden size
        """
        # Chop of the <END> token for max length sentences.
        target_padded = target_padded[:-1]

        # Initialize the decoder state (hidden and cell)
        dec_state = dec_init_state

        # Initialize previous combined output vector o_{t-1} as zero
        batch_size = enc_hiddens.size(0)
        o_prev = torch.zeros(batch_size, self.hidden_size, device=self.device)

        # Initialize a list we will use to collect the combined output o_t on each step
        combined_outputs = []

        enc_hiddens_proj = self.att_projection(enc_hiddens) # (b, src_len, h)
        Y = self.model_embeddings.target(target_padded) # (tgt_len, b, e)
        for Y_t in torch.split(Y, 1, dim=0):
            Y_t = torch.squeeze(Y_t, 0) # (b, e)
            Ybar_t = torch.cat((Y_t, o_prev), 1)
            dec_state, o_t, e_t = self.step(Ybar_t, dec_state, enc_hiddens, enc_hiddens_proj, enc_masks)
            combined_outputs.append(o_t)
            o_prev = o_t
        combined_outputs = torch.stack(combined_outputs, dim=0) # (tgt_len, b, h)

        return combined_outputs


    def step(self, Ybar_t: torch.Tensor,
            dec_state: Tuple[torch.Tensor, torch.Tensor],
            enc_hiddens: torch.Tensor,
            enc_hiddens_proj: torch.Tensor,
            enc_masks: torch.Tensor) -> Tuple[Tuple, torch.Tensor, torch.Tensor]:
        """ Compute one forward step of the LSTM decoder, including the attention computation.

        @param Ybar_t (Tensor): Concatenated Tensor of [Y_t o_prev], with shape (b, e + h). The input for the decoder,
                                where b = batch size, e = embedding size, h = hidden size.
        @param dec_state (tuple(Tensor, Tensor)): Tuple of tensors both with shape (b, h), where b = batch size, h = hidden size.
                First tensor is decoder's prev hidden state, second tensor is decoder's prev cell.
        @param enc_hiddens (Tensor): Encoder hidden states Tensor, with shape (b, src_len, h * 2), where b = batch size,
                                    src_len = maximum source length, h = hidden size.
        @param enc_hiddens_proj (Tensor): Encoder hidden states Tensor, projected from (h * 2) to h. Tensor is with shape (b, src_len, h),
                                    where b = batch size, src_len = maximum source length, h = hidden size.
        @param enc_masks (Tensor): Tensor of sentence masks shape (b, src_len),
                                    where b = batch size, src_len is maximum source length.

        @returns dec_state (tuple (Tensor, Tensor)): Tuple of tensors both shape (b, h), where b = batch size, h = hidden size.
                First tensor is decoder's new hidden state, second tensor is decoder's new cell.
        @returns combined_output (Tensor): Combined output Tensor at timestep t, shape (b, h), where b = batch size, h = hidden size.
        @returns e_t (Tensor): Tensor of shape (b, src_len). It is attention scores distribution.
                                Note: You will not use this outside of this function.
                                      We are simply returning this value so that we can sanity check
                                      your implementation.
        """

        combined_output = None
        dec_state = self.decoder(Ybar_t, dec_state)
        dec_hidden, dec_cell = dec_state
        e_t = torch.squeeze(torch.bmm(enc_hiddens_proj, torch.unsqueeze(dec_hidden, dim=2)), dim=2)

        # Set e_t to -inf where enc_masks has 1 to ignore <pad> tokens
        if enc_masks is not None:
            e_t.data.masked_fill_(enc_masks.bool(), -float('inf'))

        alpha_t = F.softmax(e_t, dim=1) # (b, src_len)
        a_t = torch.squeeze(torch.bmm(torch.unsqueeze(alpha_t, 1), enc_hiddens), dim=1) # (b, 2h)
        U_t = torch.cat((dec_hidden, a_t), dim=1)
        V_t = self.combined_output_projection(U_t)
        O_t = self.dropout(self.activation(V_t))

        combined_output = O_t
        return dec_state, combined_output, e_t

    def generate_sent_masks(self, enc_hiddens: torch.Tensor, source_lengths: List[int]) -> torch.Tensor:
        """ Generate sentence masks for encoder hidden states.

        @param enc_hiddens (Tensor): encodings of shape (b, src_len, 2*h), where b = batch size,
                                     src_len = max source length, h = hidden size.
        @param source_lengths (List[int]): List of actual lengths for each of the sentences in the batch.

        @returns enc_masks (Tensor): Tensor of sentence masks of shape (b, src_len),
                                    where src_len = max source length, h = hidden size.
        """
        enc_masks = torch.zeros(enc_hiddens.size(0), enc_hiddens.size(1), dtype=torch.float)
        for e_id, src_len in enumerate(source_lengths):
            enc_masks[e_id, src_len:] = 1
        return enc_masks.to(self.device)


    def beam_search(self, src_sent: List[str], beam_size: int=5, max_decoding_time_step: int=70) -> List[Hypothesis]:
        """ Given a single source sentence, perform beam search, yielding translations in the target language.
        @param src_sent (List[str]): a single source sentence (words)
        @param beam_size (int): beam size
        @param max_decoding_time_step (int): maximum number of time steps to unroll the decoding RNN
        @returns hypotheses (List[Hypothesis]): a list of hypothesis, each hypothesis has two fields:
                value: List[str]: the decoded target sentence, represented as a list of words
                score: float: the log-likelihood of the target sentence
        """
        src_sents_var = self.vocab.src.to_input_tensor([src_sent], self.device)

        src_encodings, dec_init_vec = self.encode(src_sents_var, [len(src_sent)])
        src_encodings_att_linear = self.att_projection(src_encodings)

        h_tm1 = dec_init_vec
        att_tm1 = torch.zeros(1, self.hidden_size, device=self.device)

        eos_id = self.vocab.tgt['</s>']

        hypotheses = [['<s>']]
        hyp_scores = torch.zeros(len(hypotheses), dtype=torch.float, device=self.device)
        completed_hypotheses = []

        t = 0
        while len(completed_hypotheses) < beam_size and t < max_decoding_time_step:
            t += 1
            hyp_num = len(hypotheses)

            exp_src_encodings = src_encodings.expand(hyp_num,
                                                     src_encodings.size(1),
                                                     src_encodings.size(2))

            exp_src_encodings_att_linear = src_encodings_att_linear.expand(hyp_num,
                                                                           src_encodings_att_linear.size(1),
                                                                           src_encodings_att_linear.size(2))

            y_tm1 = torch.tensor([self.vocab.tgt[hyp[-1]] for hyp in hypotheses], dtype=torch.long, device=self.device)
            y_t_embed = self.model_embeddings.target(y_tm1)

            x = torch.cat([y_t_embed, att_tm1], dim=-1)

            (h_t, cell_t), att_t, _  = self.step(x, h_tm1,
                                                      exp_src_encodings, exp_src_encodings_att_linear, enc_masks=None)

            # log probabilities over target words
            log_p_t = F.log_softmax(self.target_vocab_projection(att_t), dim=-1)

            live_hyp_num = beam_size - len(completed_hypotheses)
            contiuating_hyp_scores = (hyp_scores.unsqueeze(1).expand_as(log_p_t) + log_p_t).view(-1)
            top_cand_hyp_scores, top_cand_hyp_pos = torch.topk(contiuating_hyp_scores, k=live_hyp_num)

            prev_hyp_ids = top_cand_hyp_pos // len(self.vocab.tgt)
            hyp_word_ids = top_cand_hyp_pos % len(self.vocab.tgt)

            new_hypotheses = []
            live_hyp_ids = []
            new_hyp_scores = []

            for prev_hyp_id, hyp_word_id, cand_new_hyp_score in zip(prev_hyp_ids, hyp_word_ids, top_cand_hyp_scores):
                prev_hyp_id = prev_hyp_id.item()
                hyp_word_id = hyp_word_id.item()
                cand_new_hyp_score = cand_new_hyp_score.item()

                hyp_word = self.vocab.tgt.id2word[hyp_word_id]
                new_hyp_sent = hypotheses[prev_hyp_id] + [hyp_word]
                if hyp_word == '</s>':
                    completed_hypotheses.append(Hypothesis(value=new_hyp_sent[1:-1],
                                                           score=cand_new_hyp_score))
                else:
                    new_hypotheses.append(new_hyp_sent)
                    live_hyp_ids.append(prev_hyp_id)
                    new_hyp_scores.append(cand_new_hyp_score)

            if len(completed_hypotheses) == beam_size:
                break

            live_hyp_ids = torch.tensor(live_hyp_ids, dtype=torch.long, device=self.device)
            h_tm1 = (h_t[live_hyp_ids], cell_t[live_hyp_ids])
            att_tm1 = att_t[live_hyp_ids]

            hypotheses = new_hypotheses
            hyp_scores = torch.tensor(new_hyp_scores, dtype=torch.float, device=self.device)

        if len(completed_hypotheses) == 0:
            completed_hypotheses.append(Hypothesis(value=hypotheses[0][1:],
                                                   score=hyp_scores[0].item()))

        completed_hypotheses.sort(key=lambda hyp: hyp.score, reverse=True)

        return completed_hypotheses

    @property
    def device(self) -> torch.device:
        """ Determine which device to place the Tensors upon, CPU or GPU.
        """
        return self.model_embeddings.source.weight.device

    @staticmethod
    def load(model_path: str):
        """ Load the model from a file.
        @param model_path (str): path to model
        """
        params = torch.load(model_path, map_location=lambda storage, loc: storage,weights_only=False)
        args = params['args']
        if 'bidirectional' not in args:
            print("WARNING: 'bidirectional' key not found in saved args. Forcing True for decoding.", file=sys.stderr)
            args['bidirectional'] = True
        model = NMT(vocab=params['vocab'], **args)
        model.load_state_dict(params['state_dict'])

        return model

    def save(self, path: str):
        """ Save the odel to a file.
        @param path (str): path to the model
        """
        print('save model parameters to [%s]' % path, file=sys.stderr)

        params = {
            'args': dict(embed_size=self.model_embeddings.embed_size, hidden_size=self.hidden_size, dropout_rate=self.dropout_rate, rnn_layer=self.rnn_layer, num_layers=self.num_layers, activation=self.activation),
            'vocab': self.vocab,
            'state_dict': self.state_dict()
        }

        torch.save(params, path)

# %%
# -----------------------------------------------------------------
# 📜 代码块 1: 超参数配置
# 在这里设置所有的运行参数
# -----------------------------------------------------------------

import torch

# --- 模式设置 ---
# 'train' 或 'decode'
MODE = 'train'

# --- 核心文件路径 (你的命令) ---
TRAIN_SRC_FILE = 'train.zh'
TRAIN_TGT_FILE = 'train.en'
DEV_SRC_FILE = 'dev.zh'
DEV_TGT_FILE = 'dev.en'
VOCAB_FILE = 'vocab_zh_en.json'

# --- 训练超参数 (你的命令) ---
USE_CUDA = True
LEARNING_RATE = 5e-4
PATIENCE = 1
VALID_NITER = 1000
BATCH_SIZE = 32
DROPOUT_RATE = 0.25


SEED = 0
EMBED_SIZE = 512
HIDDEN_SIZE = 512
CLIP_GRAD = 5.0
LOG_EVERY = 10
MAX_EPOCH = 30
MAX_NUM_TRIAL = 5
LR_DECAY = 0.5
UNIFORM_INIT = 0.1
SAVE_TO_PATH = 'model.bin' # 默认模型保存路径

# --- Decode 模式参数 (如果 MODE = 'decode'，则需要设置这些) ---
MODEL_PATH = 'model.bin'
TEST_SOURCE_FILE = 'test.zh'
TEST_TARGET_FILE = 'test.en'
OUTPUT_FILE = 'outputs/test_outputs.txt'
BEAM_SIZE = 10
MAX_DECODING_TIME_STEP = 70

# -----------------------------------------------------------------
# 结束配置
# -----------------------------------------------------------------

print("✅ 超参数配置加载完毕。")
print(f"模式: {MODE}")
print(f"使用设备: {'cuda' if USE_CUDA else 'cpu'}")
# Out:
# ✅ 超参数配置加载完毕。
# 模式: train
# 使用设备: cuda

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

"""
注意：此脚本已重构。
它会从全局作用域读取在"代码块 1"中定义的超参数变量。
"""
import math
import sys
import time
import os

# 确保库已安装
try:
    import sacrebleu
    from tqdm import tqdm
    import torch
    import torch.nn.utils
    from torch import nn
    import numpy as np
except ImportError:
    print("="*80)
    print("错误：缺少必要的库。请先运行：")
    print("pip install torch numpy tqdm sacrebleu")
    print("="*80)
    sys.exit(1)

from typing import List, Tuple, Dict, Set, Union

# 假设这些本地文件与此脚本位于同一目录





# -----------------------------------------------------------------
# 辅助函数 (无需修改)
# -----------------------------------------------------------------

def evaluate_ppl(model, dev_data, batch_size=32):
    """ Evaluate perplexity on dev sentences """
    was_training = model.training
    model.eval()

    cum_loss = 0.
    cum_tgt_words = 0.

    with torch.no_grad():
        for src_sents, tgt_sents in batch_iter(dev_data, batch_size):
            loss = -model(src_sents, tgt_sents).sum()

            cum_loss += loss.item()
            tgt_word_num_to_predict = sum(len(s[1:]) for s in tgt_sents)  # omitting leading `<s>`
            cum_tgt_words += tgt_word_num_to_predict

        ppl = np.exp(cum_loss / cum_tgt_words)

    if was_training:
        model.train()

    return ppl


def compute_corpus_level_bleu_score(references: List[List[str]], hypotheses: List[Hypothesis]) -> float:
    """ Given decoding results and reference sentences, compute corpus-level BLEU score. """
    if references[0][0] == '<s>':
        references = [ref[1:-1] for ref in references]

    detokened_refs = [''.join(pieces).replace(' ', ' ') for pieces in references]
    detokened_hyps = [''.join(hyp.value).replace(' ', ' ') for hyp in hypotheses]

    # print(detokened_refs) # 调试时取消注释
    # print(detokened_hyps) # 调试时取消注释

    bleu = sacrebleu.corpus_bleu(detokened_hyps, [detokened_refs])

    return bleu.score

def beam_search(model: NMT, test_data_src: List[List[str]], beam_size: int, max_decoding_time_step: int) -> List[List[Hypothesis]]:
    """ Run beam search to construct hypotheses for a list of src-language sentences. """
    was_training = model.training
    model.eval()

    hypotheses = []
    with torch.no_grad():
        for src_sent in tqdm(test_data_src, desc='Decoding', file=sys.stdout):
            example_hyps = model.beam_search(src_sent, beam_size=beam_size, max_decoding_time_step=max_decoding_time_step)
            hypotheses.append(example_hyps)

    if was_training:
        model.train(was_training)

    return hypotheses


# -----------------------------------------------------------------
# 核心函数: train() - 已重构
# -----------------------------------------------------------------

def train():

    print("开始读取和处理训练数据...")
    # 参数在第二个block定义
    train_data_src = read_corpus(TRAIN_SRC_FILE, source='src', vocab_size=PARAM_SRC_VOCAB_SIZE)
    train_data_tgt = read_corpus(TRAIN_TGT_FILE, source='tgt', vocab_size=PARAM_TGT_VOCAB_SIZE)

    print("开始读取和处理开发(dev)数据...")
    dev_data_src = read_corpus(DEV_SRC_FILE, source='src', vocab_size=3000)
    dev_data_tgt = read_corpus(DEV_TGT_FILE, source='tgt', vocab_size=2000)

    train_data = list(zip(train_data_src, train_data_tgt))
    dev_data = list(zip(dev_data_src, dev_data_tgt))

    # 从代码块1中获取参数
    train_batch_size = BATCH_SIZE
    clip_grad = CLIP_GRAD
    valid_niter = VALID_NITER
    log_every = LOG_EVERY
    model_save_path = SAVE_TO_PATH

    print(f"从 {VOCAB_FILE} 加载词汇表...")
    vocab = Vocab.load(VOCAB_FILE)

    print("初始化 NMT 模型...")
    model = NMT(embed_size=EMBED_SIZE,
                hidden_size=HIDDEN_SIZE,
                dropout_rate=DROPOUT_RATE,
                vocab=vocab,
                rnn_layer=nn.LSTM,
                bidirectional=True)
    model.train()

    # 参数初始化
    uniform_init = UNIFORM_INIT
    if np.abs(uniform_init) > 0.:
        print(f'uniformly initialize parameters [-%f, +%f]' % (uniform_init, uniform_init), file=sys.stderr)
        for p in model.parameters():
            p.data.uniform_(-uniform_init, uniform_init)

    vocab_mask = torch.ones(len(vocab.tgt))
    vocab_mask[vocab.tgt['<pad>']] = 0

    device = torch.device("cuda:0" if USE_CUDA else "cpu")
    print(f'使用设备: {device}', file=sys.stderr)

    model = model.to(device)

    optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

    num_trial = 0
    train_iter = patience = cum_loss = report_loss = cum_tgt_words = report_tgt_words = 0
    cum_examples = report_examples = epoch = valid_num = 0
    hist_valid_scores = []
    train_time = begin_time = time.time()

    print('======== 开始训练 ========')
    train_ppl_log = open("ppl.log", "w")
    dev_ppl_log = open("dev_ppl.log", "w")

    while True:
        epoch += 1
        print(f"--- 开始 Epoch {epoch} ---")

        for src_sents, tgt_sents in batch_iter(train_data, batch_size=train_batch_size, shuffle=True):
            train_iter += 1

            optimizer.zero_grad()
            batch_size = len(src_sents)

            example_losses = -model(src_sents, tgt_sents) # (batch_size,)
            batch_loss = example_losses.sum()
            loss = batch_loss / batch_size

            loss.backward()
            grad_norm = torch.nn.utils.clip_grad_norm_(model.parameters(), clip_grad)
            optimizer.step()

            batch_losses_val = batch_loss.item()
            report_loss += batch_losses_val
            cum_loss += batch_losses_val

            tgt_words_num_to_predict = sum(len(s[1:]) for s in tgt_sents)  # omitting leading `<s>`
            report_tgt_words += tgt_words_num_to_predict
            cum_tgt_words += tgt_words_num_to_predict
            report_examples += batch_size
            cum_examples += batch_size

            if train_iter % log_every == 0:
                print('epoch %d, iter %d, avg. loss %.2f, avg. ppl %.2f ' \
                      'cum. examples %d, speed %.2f words/sec, time elapsed %.2f sec' % (epoch, train_iter,
                                                                                       report_loss / report_examples,
                                                                                       math.exp(report_loss / report_tgt_words),
                                                                                       cum_examples,
                                                                                       report_tgt_words / (time.time() - train_time),
                                                                                       time.time() - begin_time), file=sys.stderr)
                train_ppl_log.write("{} {}\n".format(train_iter, math.exp(report_loss / report_tgt_words)))
                train_time = time.time()
                report_loss = report_tgt_words = report_examples = 0.

            # perform validation
            if train_iter % valid_niter == 0:
                print(f'\n[Validation] epoch {epoch}, iter {train_iter}, cum. loss %.2f, cum. ppl %.2f cum. examples %d' % (
                                                                                       cum_loss / cum_examples,
                                                                                       np.exp(cum_loss / cum_tgt_words),
                                                                                       cum_examples), file=sys.stderr)

                cum_loss = cum_examples = cum_tgt_words = 0.
                valid_num += 1
                print('begin validation ...', file=sys.stderr)

                dev_ppl = evaluate_ppl(model, dev_data, batch_size=128)   # dev batch size can be a bit larger
                valid_metric = -dev_ppl

                print(f'[Validation] iter {train_iter}, dev. ppl {dev_ppl}', file=sys.stderr)
                dev_ppl_log.write("{} {}\n".format(train_iter, dev_ppl))

                is_better = len(hist_valid_scores) == 0 or valid_metric > max(hist_valid_scores)
                hist_valid_scores.append(valid_metric)

                if is_better:
                    patience = 0
                    print(f'保存当前最佳模型到 [{model_save_path}]', file=sys.stderr)
                    model.save(model_save_path)
                    torch.save(optimizer.state_dict(), model_save_path + '.optim')
                elif patience < PATIENCE:
                    patience += 1
                    print(f'hit patience {patience}', file=sys.stderr)

                    if patience == PATIENCE:
                        num_trial += 1
                        print(f'hit #{num_trial} trial', file=sys.stderr)
                        if num_trial == MAX_NUM_TRIAL:
                            print('Early stop!', file=sys.stderr)
                            train_ppl_log.close()
                            dev_ppl_log.close()
                            return # 退出 train() 函数

                        # 衰减学习率并恢复
                        lr = optimizer.param_groups[0]['lr'] * LR_DECAY
                        print(f'load previously best model and decay learning rate to {lr}', file=sys.stderr)

                        params = torch.load(model_save_path, map_location=lambda storage, loc: storage, weights_only=False)
                        model.load_state_dict(params['state_dict'])
                        model = model.to(device)

                        print('restore parameters of the optimizers', file=sys.stderr)
                        optimizer.load_state_dict(torch.load(model_save_path + '.optim'))

                        for param_group in optimizer.param_groups:
                            param_group['lr'] = lr

                        patience = 0
                print("-" * 30 + "\n")

        if epoch == MAX_EPOCH:
            print('达到最大 epoch 数量!', file=sys.stderr)
            train_ppl_log.close()
            dev_ppl_log.close()
            return # 退出 train() 函数


# -----------------------------------------------------------------
# 核心函数: decode() - 已重构
# -----------------------------------------------------------------

def decode():
    """ Performs decoding on a test set.
    (已重构：此函数现在直接从全局作用域读取超参数)
    """
    print("======== 开始解码(Decode) ========")
    print(f"load test source sentences from [{TEST_SOURCE_FILE}]", file=sys.stderr)
    test_data_src = read_corpus(TEST_SOURCE_FILE, source='src', vocab_size=3000)

    test_data_tgt = None
    if TEST_TARGET_FILE:
        print(f"load test target sentences from [{TEST_TARGET_FILE}]", file=sys.stderr)
        test_data_tgt = read_corpus(TEST_TARGET_FILE, source='tgt', vocab_size=2000)

    print(f"load model from {MODEL_PATH}", file=sys.stderr)
    model = NMT.load(MODEL_PATH)

    if USE_CUDA:
        model = model.to(torch.device("cuda:0"))

    # 注意：原始代码在 decode() 中硬编码了 beam_size=10
    hypotheses = beam_search(model, test_data_src,
                             beam_size=BEAM_SIZE,
                             max_decoding_time_step=MAX_DECODING_TIME_STEP)

    if test_data_tgt:
        top_hypotheses = [hyps[0] for hyps in hypotheses]
        bleu_score = compute_corpus_level_bleu_score(test_data_tgt, top_hypotheses)
        print(f'Corpus BLEU: {bleu_score}', file=sys.stderr)

    # 创建输出目录
    output_file_path = OUTPUT_FILE
    output_dir = os.path.dirname(output_file_path)
    if output_dir and not os.path.exists(output_dir):
        print(f"创建输出目录: {output_dir}", file=sys.stderr)
        os.makedirs(output_dir)

    with open(output_file_path, 'w', encoding='utf-8') as f:
        for src_sent, hyps in zip(test_data_src, hypotheses):
            top_hyp = hyps[0]
            # detokenize
            src_sent_str = ''.join(src_sent).replace(' ', ' ')
            hyp_sent_str = ''.join(top_hyp.value).replace(' ', ' ')

            f.write(src_sent_str + '\n')
            f.write(hyp_sent_str + '\n\n')

    print(f"解码完成，输出已保存到 {output_file_path}")

# %%
# 检查 PyTorch 版本
assert(torch.__version__ >= "1.0.0"), "Please update your installation of PyTorch. You have {} and you should have version 1.0.0".format(torch.__version__)

# 设置随机种子 (从代码块1读取)
torch.manual_seed(SEED)
if USE_CUDA:
    torch.cuda.manual_seed(SEED)
np.random.seed(SEED * 13 // 7)

# 检查代码块1中设置的模式
if MODE == 'train':
    train()
elif MODE == 'decode':
    decode()
else:
    raise RuntimeError(f'无效的运行模式: {MODE} (请在代码块1中设置为 "train" 或 "decode")')
# Out:
# 开始读取和处理训练数据...
# 开始读取和处理开发(dev)数据...
# 从 vocab_zh_en.json 加载词汇表...
# Loading vocabulary from vocab_zh_en.json...
# 初始化 NMT 模型...
# uniformly initialize parameters [-0.100000, +0.100000]
# 使用设备: cuda:0
# ======== 开始训练 ========
# --- 开始 Epoch 1 ---
# torch.Size([32, 41, 1024])
# ****************************************
# torch.Size([32, 60, 1024])
# ****************************************
# torch.Size([32, 58, 1024])
# ****************************************
# torch.Size([32, 51, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 65, 1024])
# ****************************************
# torch.Size([32, 58, 1024])
# ****************************************
# torch.Size([32, 84, 1024])
# ****************************************
# torch.Size([32, 58, 1024])
# ****************************************
# torch.Size([32, 48, 1024])
# ****************************************
# torch.Size([32, 55, 1024])
# ****************************************
# epoch 1, iter 10, avg. loss 257.23, avg. ppl 4244.33 cum. examples 320, speed 4394.24 words/sec, time elapsed 2.24 sec
# torch.Size([32, 65, 1024])
# ****************************************
# torch.Size([32, 65, 1024])
# ****************************************
# torch.Size([32, 47, 1024])
# ****************************************
# torch.Size([32, 77, 1024])
# ****************************************
# torch.Size([32, 51, 1024])
# ****************************************
# torch.Size([32, 84, 1024])
# ****************************************
# torch.Size([32, 48, 1024])
# ****************************************
# torch.Size([32, 54, 1024])
# ****************************************
# torch.Size([32, 55, 1024])
# ****************************************
# torch.Size([32, 64, 1024])
# ****************************************
# torch.Size([32, 74, 1024])
# ****************************************
# epoch 1, iter 20, avg. loss 226.87, avg. ppl 1669.44 cum. examples 640, speed 10590.25 words/sec, time elapsed 3.17 sec
# torch.Size([32, 97, 1024])
# ****************************************
# torch.Size([32, 57, 1024])
# ****************************************
# torch.Size([32, 88, 1024])
# ****************************************
# torch.Size([32, 86, 1024])
# ****************************************
# torch.Size([32, 62, 1024])
# ****************************************
# torch.Size([32, 67, 1024])
# ****************************************
# torch.Size([32, 50, 1024])
# ****************************************
# torch.Size([32, 75, 1024])
# ****************************************
# torch.Size([32, 51, 1024])
# ****************************************
# epoch 1, iter 30, avg. loss 226.94, avg. ppl 1300.44 cum. examples 960, speed 9377.71 words/sec, time elapsed 4.25 sec
# torch.Size([32, 57, 1024])
# ****************************************
# torch.Size([32, 75, 1024])
# ****************************************
# torch.Size([32, 44, 1024])
# ****************************************
# torch.Size([32, 77, 1024])
# ****************************************
# torch.Size([32, 63, 1024])
# ****************************************
# torch.Size([32, 62, 1024])
# ****************************************
# torch.Size([32, 52, 1024])
# ****************************************
# torch.Size([32, 97, 1024])
# ****************************************
# torch.Size([32, 58, 1024])
# ****************************************
# torch.Size([32, 62, 1024])
# ****************************************
# torch.Size([32, 61, 1024])
# ****************************************
# epoch 1, iter 40, avg. loss 224.30, avg. ppl 1169.69 cum. examples 1280, speed 10090.51 words/sec, time elapsed 5.25 sec
# torch.Size([32, 61, 1024])
# ****************************************
# torch.Size([32, 71, 1024])
# ****************************************
# torch.Size([32, 64, 1024])
# ****************************************
# torch.Size([32, 54, 1024])
# ****************************************
# torch.Size([32, 44, 1024])
# ****************************************
# torch.Size([32, 60, 1024])
# ****************************************
# torch.Size([32, 56, 1024])
# ****************************************
# torch.Size([32, 54, 1024])
# ****************************************
# epoch 1, iter 50, avg. loss 212.72, avg. ppl 1009.92 cum. examples 1600, speed 10701.13 words/sec, time elapsed 6.17 sec
# torch.Size([32, 59, 1024])
# ****************************************
# torch.Size([32, 52, 1024])
# ****************************************
# torch.Size([32, 43, 1024])
# ****************************************
# torch.Size([32, 67, 1024])
# ****************************************
# torch.Size([32, 77, 1024])
# ****************************************
# torch.Size([32, 55, 1024])
# ****************************************
# torch.Size([32, 62, 1024])
# ****************************************
# torch.Size([32, 52, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 46, 1024])
# ****************************************
# epoch 1, iter 60, avg. loss 215.86, avg. ppl 1035.08 cum. examples 1920, speed 10974.95 words/sec, time elapsed 7.08 sec
# torch.Size([32, 44, 1024])
# ****************************************
# torch.Size([32, 117, 1024])
# ****************************************
# torch.Size([32, 52, 1024])
# ****************************************
# torch.Size([32, 46, 1024])
# ****************************************
# torch.Size([32, 41, 1024])
# ****************************************
# torch.Size([32, 51, 1024])
# ****************************************
# torch.Size([32, 63, 1024])
# ****************************************
# torch.Size([32, 64, 1024])
# ****************************************
# torch.Size([32, 55, 1024])
# ****************************************
# epoch 1, iter 70, avg. loss 215.98, avg. ppl 918.98 cum. examples 2240, speed 11515.53 words/sec, time elapsed 7.96 sec
# torch.Size([32, 48, 1024])
# ****************************************
# torch.Size([32, 57, 1024])
# ****************************************
# torch.Size([32, 43, 1024])
# ****************************************
# torch.Size([32, 45, 1024])
# ****************************************
# torch.Size([32, 54, 1024])
# ****************************************
# torch.Size([32, 80, 1024])
# ****************************************
# torch.Size([32, 47, 1024])
# ****************************************
# torch.Size([32, 47, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 60, 1024])
# ****************************************
# torch.Size([32, 69, 1024])
# ****************************************
# epoch 1, iter 80, avg. loss 207.11, avg. ppl 921.57 cum. examples 2560, speed 11401.31 words/sec, time elapsed 8.81 sec
# torch.Size([32, 68, 1024])
# ****************************************
# torch.Size([32, 60, 1024])
# ****************************************
# torch.Size([32, 56, 1024])
# ****************************************
# torch.Size([32, 52, 1024])
# ****************************************
# torch.Size([32, 47, 1024])
# ****************************************
# torch.Size([32, 61, 1024])
# ****************************************
# torch.Size([32, 64, 1024])
# ****************************************
# torch.Size([32, 48, 1024])
# ****************************************
# torch.Size([32, 68, 1024])
# ****************************************
# epoch 1, iter 90, avg. loss 203.14, avg. ppl 850.66 cum. examples 2880, speed 10806.26 words/sec, time elapsed 9.70 sec
# torch.Size([32, 37, 1024])
# ****************************************
# torch.Size([32, 76, 1024])
# ****************************************
# torch.Size([32, 50, 1024])
# ****************************************
# torch.Size([32, 77, 1024])
# ****************************************
# torch.Size([32, 81, 1024])
# ****************************************
# torch.Size([32, 41, 1024])
# ****************************************
# torch.Size([32, 71, 1024])
# ****************************************
# torch.Size([32, 45, 1024])
# ****************************************
# torch.Size([32, 45, 1024])
# ****************************************
# epoch 1, iter 100, avg. loss 206.77, avg. ppl 846.79 cum. examples 3200, speed 11761.05 words/sec, time elapsed 10.54 sec
# torch.Size([32, 93, 1024])
# ****************************************
# torch.Size([32, 55, 1024])
# ****************************************
# torch.Size([32, 55, 1024])
# ****************************************
# torch.Size([32, 52, 1024])
# ****************************************
# torch.Size([32, 60, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 56, 1024])
# ****************************************
# torch.Size([32, 51, 1024])
# ****************************************
# torch.Size([32, 72, 1024])
# ****************************************
# torch.Size([32, 46, 1024])
# ****************************************
# torch.Size([32, 39, 1024])
# ****************************************
# torch.Size([32, 41, 1024])
# ****************************************
# epoch 1, iter 110, avg. loss 204.37, avg. ppl 766.73 cum. examples 3520, speed 11081.91 words/sec, time elapsed 11.43 sec
# torch.Size([32, 70, 1024])
# ****************************************
# torch.Size([32, 51, 1024])
# ****************************************
# torch.Size([32, 70, 1024])
# ****************************************
# torch.Size([32, 37, 1024])
# ****************************************
# torch.Size([32, 111, 1024])
# ****************************************
# torch.Size([32, 45, 1024])
# ****************************************
# torch.Size([32, 118, 1024])
# ****************************************
# torch.Size([32, 52, 1024])
# ****************************************
# epoch 1, iter 120, avg. loss 202.67, avg. ppl 761.15 cum. examples 3840, speed 10051.45 words/sec, time elapsed 12.40 sec
# torch.Size([32, 47, 1024])
# ****************************************
# torch.Size([32, 66, 1024])
# ****************************************
# torch.Size([32, 38, 1024])
# ****************************************
# torch.Size([32, 49, 1024])
# ****************************************
# torch.Size([32, 62, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 49, 1024])
# ****************************************
# torch.Size([32, 62, 1024])
# ****************************************
# torch.Size([32, 46, 1024])
# ****************************************
# torch.Size([32, 48, 1024])
# ****************************************
# torch.Size([32, 88, 1024])
# ****************************************
# epoch 1, iter 130, avg. loss 205.04, avg. ppl 712.85 cum. examples 4160, speed 11418.23 words/sec, time elapsed 13.27 sec
# torch.Size([32, 45, 1024])
# ****************************************
# torch.Size([32, 51, 1024])
# ****************************************
# torch.Size([32, 54, 1024])
# ****************************************
# torch.Size([32, 42, 1024])
# ****************************************
# torch.Size([32, 55, 1024])
# ****************************************
# torch.Size([32, 49, 1024])
# ****************************************
# torch.Size([32, 56, 1024])
# ****************************************
# torch.Size([32, 55, 1024])
# ****************************************
# torch.Size([32, 54, 1024])
# ****************************************
# epoch 1, iter 140, avg. loss 201.62, avg. ppl 684.62 cum. examples 4480, speed 10246.68 words/sec, time elapsed 14.24 sec
# torch.Size([32, 62, 1024])
# ****************************************
# torch.Size([32, 126, 1024])
# ****************************************
# torch.Size([32, 43, 1024])
# ****************************************
# torch.Size([32, 47, 1024])
# ****************************************
# torch.Size([32, 44, 1024])
# ****************************************
# torch.Size([32, 49, 1024])
# ****************************************
# torch.Size([32, 54, 1024])
# ****************************************
# torch.Size([32, 49, 1024])
# ****************************************
# torch.Size([32, 43, 1024])
# ****************************************
# torch.Size([32, 55, 1024])
# ****************************************
# torch.Size([32, 62, 1024])
# ****************************************
# epoch 1, iter 150, avg. loss 193.23, avg. ppl 668.17 cum. examples 4800, speed 10909.32 words/sec, time elapsed 15.11 sec
# torch.Size([32, 50, 1024])
# ****************************************
# torch.Size([32, 82, 1024])
# ****************************************
# torch.Size([32, 54, 1024])
# ****************************************
# torch.Size([32, 38, 1024])
# ****************************************
# torch.Size([32, 45, 1024])
# ****************************************
# torch.Size([32, 46, 1024])
# ****************************************
# torch.Size([32, 44, 1024])
# ****************************************
# torch.Size([32, 49, 1024])
# ****************************************
# torch.Size([32, 81, 1024])
# ****************************************
# epoch 1, iter 160, avg. loss 201.50, avg. ppl 669.86 cum. examples 5120, speed 10594.10 words/sec, time elapsed 16.05 sec
# torch.Size([32, 39, 1024])
# ****************************************
# torch.Size([32, 41, 1024])
# ****************************************
# torch.Size([32, 68, 1024])
# ****************************************
# torch.Size([32, 58, 1024])
# ****************************************
# torch.Size([32, 57, 1024])
# ****************************************
# torch.Size([32, 46, 1024])
# ****************************************
# torch.Size([32, 50, 1024])
# ****************************************
# torch.Size([32, 68, 1024])
# ****************************************
# torch.Size([32, 50, 1024])
# ****************************************
# torch.Size([32, 55, 1024])
# ****************************************
# torch.Size([32, 78, 1024])
# ****************************************
# torch.Size([32, 47, 1024])
# ****************************************
# epoch 1, iter 170, avg. loss 189.06, avg. ppl 618.92 cum. examples 5440, speed 11376.03 words/sec, time elapsed 16.87 sec
# torch.Size([32, 49, 1024])
# ****************************************
# torch.Size([32, 39, 1024])
# ****************************************
# torch.Size([32, 52, 1024])
# ****************************************
# torch.Size([32, 56, 1024])
# ****************************************
# torch.Size([32, 83, 1024])
# ****************************************
# torch.Size([32, 56, 1024])
# ****************************************
# torch.Size([32, 74, 1024])
# ****************************************
# torch.Size([32, 62, 1024])
# ****************************************
# torch.Size([32, 45, 1024])
# ****************************************
# epoch 1, iter 180, avg. loss 192.25, avg. ppl 602.45 cum. examples 5760, speed 11260.71 words/sec, time elapsed 17.73 sec
# torch.Size([32, 64, 1024])
# ****************************************
# torch.Size([32, 69, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 117, 1024])
# ****************************************
# torch.Size([32, 67, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 69, 1024])
# ****************************************
# torch.Size([32, 56, 1024])
# ****************************************
# torch.Size([32, 60, 1024])
# ****************************************
# epoch 1, iter 190, avg. loss 204.09, avg. ppl 626.06 cum. examples 6080, speed 9340.12 words/sec, time elapsed 18.81 sec
# torch.Size([32, 57, 1024])
# ****************************************
# torch.Size([32, 46, 1024])
# ****************************************
# torch.Size([32, 44, 1024])
# ****************************************
# torch.Size([32, 82, 1024])
# ****************************************
# torch.Size([32, 45, 1024])
# ****************************************
# torch.Size([32, 57, 1024])
# ****************************************
# torch.Size([32, 45, 1024])
# ****************************************
# torch.Size([32, 64, 1024])
# ****************************************
# torch.Size([32, 63, 1024])
# ****************************************
# torch.Size([32, 59, 1024])
# ****************************************
# torch.Size([32, 57, 1024])
# ****************************************
# torch.Size([32, 48, 1024])
# ****************************************
# epoch 1, iter 200, avg. loss 195.58, avg. ppl 559.04 cum. examples 6400, speed 11126.18 words/sec, time elapsed 19.70 sec
# torch.Size([32, 70, 1024])
# ****************************************
# torch.Size([32, 56, 1024])
# ****************************************
# torch.Size([32, 49, 1024])
# ****************************************
# torch.Size([32, 54, 1024])
# ****************************************
# torch.Size([32, 56, 1024])
# ****************************************
# torch.Size([32, 51, 1024])
# ****************************************
# torch.Size([32, 49, 1024])
# ****************************************
# torch.Size([32, 70, 1024])
# ****************************************
# torch.Size([32, 49, 1024])
# ****************************************
# epoch 1, iter 210, avg. loss 199.94, avg. ppl 570.90 cum. examples 6720, speed 11307.99 words/sec, time elapsed 20.59 sec
# torch.Size([32, 44, 1024])
# ****************************************
# torch.Size([32, 68, 1024])
# ****************************************
# torch.Size([32, 78, 1024])
# ****************************************
# torch.Size([32, 55, 1024])
# ****************************************
# torch.Size([32, 118, 1024])
# ****************************************
# torch.Size([32, 51, 1024])
# ****************************************
# torch.Size([32, 51, 1024])
# ****************************************
# torch.Size([32, 45, 1024])
# ****************************************
# torch.Size([32, 58, 1024])
# ****************************************
# torch.Size([32, 47, 1024])
# ****************************************
# torch.Size([32, 66, 1024])
# ****************************************
# epoch 1, iter 220, avg. loss 183.25, avg. ppl 519.25 cum. examples 7040, speed 10521.64 words/sec, time elapsed 21.48 sec
# torch.Size([32, 55, 1024])
# ****************************************
# torch.Size([32, 70, 1024])
# ****************************************
# torch.Size([32, 46, 1024])
# ****************************************
# torch.Size([32, 57, 1024])
# ****************************************
# torch.Size([32, 51, 1024])
# ****************************************
# torch.Size([32, 82, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 57, 1024])
# ****************************************
# torch.Size([32, 48, 1024])
# ****************************************
# epoch 1, iter 230, avg. loss 195.34, avg. ppl 534.42 cum. examples 7360, speed 10654.67 words/sec, time elapsed 22.42 sec
# torch.Size([32, 66, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 51, 1024])
# ****************************************
# torch.Size([32, 62, 1024])
# ****************************************
# torch.Size([32, 59, 1024])
# ****************************************
# torch.Size([32, 46, 1024])
# ****************************************
# torch.Size([32, 61, 1024])
# ****************************************
# torch.Size([32, 45, 1024])
# ****************************************
# torch.Size([32, 59, 1024])
# ****************************************
# epoch 1, iter 240, avg. loss 187.16, avg. ppl 536.55 cum. examples 7680, speed 10864.86 words/sec, time elapsed 23.30 sec
# torch.Size([32, 73, 1024])
# ****************************************
# torch.Size([32, 51, 1024])
# ****************************************
# torch.Size([32, 91, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 48, 1024])
# ****************************************
# torch.Size([32, 74, 1024])
# ****************************************
# torch.Size([32, 56, 1024])
# ****************************************
# torch.Size([32, 63, 1024])
# ****************************************
# torch.Size([32, 52, 1024])
# ****************************************
# torch.Size([32, 61, 1024])
# ****************************************
# torch.Size([32, 50, 1024])
# ****************************************
# torch.Size([32, 78, 1024])
# ****************************************
# epoch 1, iter 250, avg. loss 193.85, avg. ppl 525.55 cum. examples 8000, speed 11070.86 words/sec, time elapsed 24.19 sec
# torch.Size([32, 48, 1024])
# ****************************************
# torch.Size([32, 62, 1024])
# ****************************************
# torch.Size([32, 56, 1024])
# ****************************************
# torch.Size([32, 61, 1024])
# ****************************************
# torch.Size([32, 56, 1024])
# ****************************************
# torch.Size([32, 63, 1024])
# ****************************************
# torch.Size([32, 98, 1024])
# ****************************************
# torch.Size([32, 49, 1024])
# ****************************************
# torch.Size([32, 57, 1024])
# ****************************************
# torch.Size([32, 59, 1024])
# ****************************************
# epoch 1, iter 260, avg. loss 195.46, avg. ppl 506.34 cum. examples 8320, speed 10667.72 words/sec, time elapsed 25.13 sec
# torch.Size([32, 73, 1024])
# ****************************************
# torch.Size([32, 61, 1024])
# ****************************************
# torch.Size([32, 54, 1024])
# ****************************************
# torch.Size([32, 48, 1024])
# ****************************************
# torch.Size([32, 67, 1024])
# ****************************************
# torch.Size([32, 51, 1024])
# ****************************************
# torch.Size([32, 80, 1024])
# ****************************************
# torch.Size([32, 93, 1024])
# ****************************************
# epoch 1, iter 270, avg. loss 202.88, avg. ppl 523.78 cum. examples 8640, speed 9591.69 words/sec, time elapsed 26.21 sec
# torch.Size([32, 43, 1024])
# ****************************************
# torch.Size([32, 61, 1024])
# ****************************************
# torch.Size([32, 78, 1024])
# ****************************************
# torch.Size([32, 49, 1024])
# ****************************************
# torch.Size([32, 48, 1024])
# ****************************************
# torch.Size([32, 68, 1024])
# ****************************************
# torch.Size([32, 96, 1024])
# ****************************************
# torch.Size([32, 46, 1024])
# ****************************************
# torch.Size([32, 42, 1024])
# ****************************************
# torch.Size([32, 48, 1024])
# ****************************************
# torch.Size([32, 61, 1024])
# ****************************************
# torch.Size([32, 50, 1024])
# ****************************************
# epoch 1, iter 280, avg. loss 184.18, avg. ppl 470.67 cum. examples 8960, speed 10722.19 words/sec, time elapsed 27.11 sec
# torch.Size([32, 57, 1024])
# ****************************************
# torch.Size([32, 97, 1024])
# ****************************************
# torch.Size([32, 47, 1024])
# ****************************************
# torch.Size([32, 76, 1024])
# ****************************************
# torch.Size([32, 46, 1024])
# ****************************************
# torch.Size([32, 60, 1024])
# ****************************************
# torch.Size([32, 48, 1024])
# ****************************************
# torch.Size([32, 50, 1024])
# ****************************************
# epoch 1, iter 290, avg. loss 186.64, avg. ppl 451.14 cum. examples 9280, speed 9891.97 words/sec, time elapsed 28.09 sec
# torch.Size([32, 46, 1024])
# ****************************************
# torch.Size([32, 83, 1024])
# ****************************************
# torch.Size([32, 50, 1024])
# ****************************************
# torch.Size([32, 48, 1024])
# ****************************************
# torch.Size([32, 54, 1024])
# ****************************************
# torch.Size([32, 45, 1024])
# ****************************************
# torch.Size([32, 57, 1024])
# ****************************************
# torch.Size([32, 72, 1024])
# ****************************************
# torch.Size([32, 69, 1024])
# ****************************************
# torch.Size([32, 51, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# epoch 1, iter 300, avg. loss 195.94, avg. ppl 460.92 cum. examples 9600, speed 10765.61 words/sec, time elapsed 29.04 sec
# torch.Size([32, 65, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 54, 1024])
# ****************************************
# torch.Size([32, 48, 1024])
# ****************************************
# torch.Size([32, 52, 1024])
# ****************************************
# torch.Size([32, 52, 1024])
# ****************************************
# torch.Size([32, 54, 1024])
# ****************************************
# torch.Size([32, 75, 1024])
# ****************************************
# epoch 1, iter 310, avg. loss 191.15, avg. ppl 436.91 cum. examples 9920, speed 11244.29 words/sec, time elapsed 29.94 sec
# torch.Size([32, 52, 1024])
# ****************************************
# torch.Size([32, 59, 1024])
# ****************************************
# torch.Size([32, 92, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 42, 1024])
# ****************************************
# torch.Size([32, 92, 1024])
# ****************************************
# torch.Size([32, 48, 1024])
# ****************************************
# torch.Size([32, 55, 1024])
# ****************************************
# torch.Size([32, 49, 1024])
# ****************************************
# torch.Size([32, 57, 1024])
# ****************************************
# torch.Size([32, 44, 1024])
# ****************************************
# torch.Size([32, 57, 1024])
# ****************************************
# epoch 1, iter 320, avg. loss 200.77, avg. ppl 443.39 cum. examples 10240, speed 11237.83 words/sec, time elapsed 30.88 sec
# torch.Size([32, 68, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 54, 1024])
# ****************************************
# torch.Size([32, 57, 1024])
# ****************************************
# torch.Size([32, 50, 1024])
# ****************************************
# torch.Size([32, 50, 1024])
# ****************************************
# torch.Size([32, 54, 1024])
# ****************************************
# torch.Size([32, 60, 1024])
# ****************************************
# epoch 1, iter 330, avg. loss 190.34, avg. ppl 427.55 cum. examples 10560, speed 11151.61 words/sec, time elapsed 31.78 sec
# torch.Size([32, 44, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 57, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 46, 1024])
# ****************************************
# torch.Size([32, 64, 1024])
# ****************************************
# torch.Size([32, 48, 1024])
# ****************************************
# torch.Size([32, 73, 1024])
# ****************************************
# torch.Size([32, 42, 1024])
# ****************************************
# torch.Size([32, 59, 1024])
# ****************************************
# torch.Size([32, 67, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# epoch 1, iter 340, avg. loss 186.85, avg. ppl 395.80 cum. examples 10880, speed 11620.64 words/sec, time elapsed 32.64 sec
# torch.Size([32, 43, 1024])
# ****************************************
# torch.Size([32, 47, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 79, 1024])
# ****************************************
# torch.Size([32, 44, 1024])
# ****************************************
# torch.Size([32, 78, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 73, 1024])
# ****************************************
# torch.Size([32, 47, 1024])
# ****************************************
# epoch 1, iter 350, avg. loss 181.46, avg. ppl 404.67 cum. examples 11200, speed 11021.19 words/sec, time elapsed 33.52 sec
# torch.Size([32, 52, 1024])
# ****************************************
# torch.Size([32, 65, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 76, 1024])
# ****************************************
# torch.Size([32, 55, 1024])
# ****************************************
# torch.Size([32, 56, 1024])
# ****************************************
# torch.Size([32, 74, 1024])
# ****************************************
# torch.Size([32, 61, 1024])
# ****************************************
# torch.Size([32, 63, 1024])
# ****************************************
# epoch 1, iter 360, avg. loss 190.14, avg. ppl 397.45 cum. examples 11520, speed 10173.90 words/sec, time elapsed 34.52 sec
# torch.Size([32, 57, 1024])
# ****************************************
# torch.Size([32, 40, 1024])
# ****************************************
# torch.Size([32, 90, 1024])
# ****************************************
# torch.Size([32, 57, 1024])
# ****************************************
# torch.Size([32, 51, 1024])
# ****************************************
# torch.Size([32, 51, 1024])
# ****************************************
# torch.Size([32, 49, 1024])
# ****************************************
# torch.Size([32, 56, 1024])
# ****************************************
# torch.Size([32, 61, 1024])
# ****************************************
# torch.Size([32, 47, 1024])
# ****************************************
# torch.Size([32, 55, 1024])
# ****************************************
# torch.Size([32, 81, 1024])
# ****************************************
# epoch 1, iter 370, avg. loss 184.81, avg. ppl 388.44 cum. examples 11840, speed 10815.92 words/sec, time elapsed 35.43 sec
# torch.Size([32, 50, 1024])
# ****************************************
# torch.Size([32, 68, 1024])
# ****************************************
# torch.Size([32, 50, 1024])
# ****************************************
# torch.Size([32, 50, 1024])
# ****************************************
# torch.Size([32, 49, 1024])
# ****************************************
# torch.Size([32, 60, 1024])
# ****************************************
# torch.Size([32, 88, 1024])
# ****************************************
# torch.Size([32, 56, 1024])
# ****************************************
# epoch 1, iter 380, avg. loss 182.07, avg. ppl 373.01 cum. examples 12160, speed 10553.49 words/sec, time elapsed 36.37 sec
# torch.Size([32, 61, 1024])
# ****************************************
# torch.Size([32, 42, 1024])
# ****************************************
# torch.Size([32, 55, 1024])
# ****************************************
# torch.Size([32, 42, 1024])
# ****************************************
# torch.Size([32, 67, 1024])
# ****************************************
# torch.Size([32, 68, 1024])
# ****************************************
# torch.Size([32, 49, 1024])
# ****************************************
# torch.Size([32, 46, 1024])
# ****************************************
# torch.Size([32, 54, 1024])
# ****************************************
# torch.Size([32, 87, 1024])
# ****************************************
# torch.Size([32, 61, 1024])
# ****************************************
# torch.Size([32, 62, 1024])
# ****************************************
# epoch 1, iter 390, avg. loss 180.63, avg. ppl 369.95 cum. examples 12480, speed 11194.05 words/sec, time elapsed 37.24 sec
# torch.Size([32, 54, 1024])
# ****************************************
# torch.Size([32, 68, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 66, 1024])
# ****************************************
# torch.Size([32, 57, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 45, 1024])
# ****************************************
# torch.Size([32, 46, 1024])
# ****************************************
# torch.Size([32, 63, 1024])
# ****************************************
# epoch 1, iter 400, avg. loss 178.66, avg. ppl 344.34 cum. examples 12800, speed 11461.07 words/sec, time elapsed 38.09 sec
# torch.Size([32, 50, 1024])
# ****************************************
# torch.Size([32, 49, 1024])
# ****************************************
# torch.Size([32, 56, 1024])
# ****************************************
# torch.Size([32, 58, 1024])
# ****************************************
# torch.Size([32, 46, 1024])
# ****************************************
# torch.Size([32, 55, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 91, 1024])
# ****************************************
# epoch 1, iter 410, avg. loss 182.95, avg. ppl 342.11 cum. examples 13120, speed 11241.84 words/sec, time elapsed 38.99 sec
# torch.Size([32, 63, 1024])
# ****************************************
# torch.Size([32, 61, 1024])
# ****************************************
# torch.Size([32, 81, 1024])
# ****************************************
# torch.Size([32, 72, 1024])
# ****************************************
# torch.Size([32, 61, 1024])
# ****************************************
# torch.Size([32, 54, 1024])
# ****************************************
# torch.Size([32, 51, 1024])
# ****************************************
# torch.Size([32, 41, 1024])
# ****************************************
# torch.Size([32, 51, 1024])
# ****************************************
# torch.Size([32, 64, 1024])
# ****************************************
# epoch 1, iter 420, avg. loss 186.41, avg. ppl 346.79 cum. examples 13440, speed 10546.11 words/sec, time elapsed 39.95 sec
# torch.Size([32, 51, 1024])
# ****************************************
# torch.Size([32, 61, 1024])
# ****************************************
# torch.Size([32, 39, 1024])
# ****************************************
# torch.Size([32, 54, 1024])
# ****************************************
# torch.Size([32, 52, 1024])
# ****************************************
# torch.Size([32, 55, 1024])
# ****************************************
# torch.Size([32, 84, 1024])
# ****************************************
# torch.Size([32, 68, 1024])
# ****************************************
# torch.Size([32, 50, 1024])
# ****************************************
# torch.Size([32, 64, 1024])
# ****************************************
# epoch 1, iter 430, avg. loss 188.82, avg. ppl 346.16 cum. examples 13760, speed 10011.91 words/sec, time elapsed 40.98 sec
# torch.Size([32, 48, 1024])
# ****************************************
# torch.Size([32, 59, 1024])
# ****************************************
# torch.Size([32, 48, 1024])
# ****************************************
# torch.Size([32, 72, 1024])
# ****************************************
# torch.Size([32, 68, 1024])
# ****************************************
# torch.Size([32, 50, 1024])
# ****************************************
# torch.Size([32, 57, 1024])
# ****************************************
# torch.Size([32, 51, 1024])
# ****************************************
# torch.Size([32, 61, 1024])
# ****************************************
# torch.Size([32, 61, 1024])
# ****************************************
# torch.Size([32, 69, 1024])
# ****************************************
# epoch 1, iter 440, avg. loss 173.64, avg. ppl 335.97 cum. examples 14080, speed 10340.63 words/sec, time elapsed 41.91 sec
# torch.Size([32, 48, 1024])
# ****************************************
# torch.Size([32, 75, 1024])
# ****************************************
# torch.Size([32, 62, 1024])
# ****************************************
# torch.Size([32, 47, 1024])
# ****************************************
# torch.Size([32, 47, 1024])
# ****************************************
# torch.Size([32, 50, 1024])
# ****************************************
# torch.Size([32, 48, 1024])
# ****************************************
# torch.Size([32, 68, 1024])
# ****************************************
# torch.Size([32, 55, 1024])
# ****************************************
# epoch 1, iter 450, avg. loss 174.94, avg. ppl 323.60 cum. examples 14400, speed 10824.47 words/sec, time elapsed 42.80 sec
# torch.Size([32, 72, 1024])
# ****************************************
# torch.Size([32, 50, 1024])
# ****************************************
# torch.Size([32, 60, 1024])
# ****************************************
# torch.Size([32, 52, 1024])
# ****************************************
# torch.Size([32, 65, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 49, 1024])
# ****************************************
# torch.Size([32, 65, 1024])
# ****************************************
# torch.Size([32, 77, 1024])
# ****************************************
# torch.Size([32, 48, 1024])
# ****************************************
# torch.Size([32, 52, 1024])
# ****************************************
# epoch 1, iter 460, avg. loss 176.76, avg. ppl 316.79 cum. examples 14720, speed 10870.35 words/sec, time elapsed 43.71 sec
# torch.Size([32, 136, 1024])
# ****************************************
# torch.Size([32, 76, 1024])
# ****************************************
# torch.Size([32, 43, 1024])
# ****************************************
# torch.Size([32, 64, 1024])
# ****************************************
# torch.Size([32, 55, 1024])
# ****************************************
# torch.Size([32, 64, 1024])
# ****************************************
# torch.Size([32, 71, 1024])
# ****************************************
# torch.Size([32, 41, 1024])
# ****************************************
# torch.Size([32, 64, 1024])
# ****************************************
# torch.Size([32, 85, 1024])
# ****************************************
# epoch 1, iter 470, avg. loss 182.81, avg. ppl 337.69 cum. examples 15040, speed 10851.72 words/sec, time elapsed 44.63 sec
# torch.Size([32, 58, 1024])
# ****************************************
# torch.Size([32, 96, 1024])
# ****************************************
# torch.Size([32, 56, 1024])
# ****************************************
# torch.Size([32, 58, 1024])
# ****************************************
# torch.Size([32, 44, 1024])
# ****************************************
# torch.Size([32, 70, 1024])
# ****************************************
# torch.Size([32, 59, 1024])
# ****************************************
# torch.Size([32, 54, 1024])
# ****************************************
# torch.Size([32, 69, 1024])
# ****************************************
# torch.Size([32, 41, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# epoch 1, iter 480, avg. loss 188.96, avg. ppl 311.27 cum. examples 15360, speed 10642.10 words/sec, time elapsed 45.62 sec
# torch.Size([32, 62, 1024])
# ****************************************
# torch.Size([32, 49, 1024])
# ****************************************
# torch.Size([32, 65, 1024])
# ****************************************
# torch.Size([32, 75, 1024])
# ****************************************
# torch.Size([32, 50, 1024])
# ****************************************
# torch.Size([32, 49, 1024])
# ****************************************
# torch.Size([32, 48, 1024])
# ****************************************
# torch.Size([32, 50, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# epoch 1, iter 490, avg. loss 173.67, avg. ppl 294.22 cum. examples 15680, speed 11347.63 words/sec, time elapsed 46.48 sec
# torch.Size([32, 85, 1024])
# ****************************************
# torch.Size([32, 59, 1024])
# ****************************************
# torch.Size([32, 50, 1024])
# ****************************************
# torch.Size([32, 71, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 92, 1024])
# ****************************************
# torch.Size([32, 43, 1024])
# ****************************************
# torch.Size([32, 62, 1024])
# ****************************************
# torch.Size([32, 52, 1024])
# ****************************************
# torch.Size([32, 62, 1024])
# ****************************************
# epoch 1, iter 500, avg. loss 175.67, avg. ppl 289.23 cum. examples 16000, speed 10892.05 words/sec, time elapsed 47.40 sec
# torch.Size([32, 66, 1024])
# ****************************************
# torch.Size([32, 64, 1024])
# ****************************************
# torch.Size([32, 51, 1024])
# ****************************************
# torch.Size([32, 50, 1024])
# ****************************************
# torch.Size([32, 42, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 46, 1024])
# ****************************************
# torch.Size([32, 58, 1024])
# ****************************************
# torch.Size([32, 57, 1024])
# ****************************************
# epoch 1, iter 510, avg. loss 170.41, avg. ppl 287.43 cum. examples 16320, speed 10656.36 words/sec, time elapsed 48.30 sec
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 66, 1024])
# ****************************************
# torch.Size([32, 60, 1024])
# ****************************************
# torch.Size([32, 51, 1024])
# ****************************************
# torch.Size([32, 79, 1024])
# ****************************************
# torch.Size([32, 69, 1024])
# ****************************************
# torch.Size([32, 46, 1024])
# ****************************************
# torch.Size([32, 44, 1024])
# ****************************************
# torch.Size([32, 77, 1024])
# ****************************************
# torch.Size([32, 41, 1024])
# ****************************************
# epoch 1, iter 520, avg. loss 179.85, avg. ppl 296.64 cum. examples 16640, speed 9500.33 words/sec, time elapsed 49.36 sec
# torch.Size([32, 54, 1024])
# ****************************************
# torch.Size([32, 48, 1024])
# ****************************************
# torch.Size([32, 63, 1024])
# ****************************************
# torch.Size([32, 48, 1024])
# ****************************************
# torch.Size([32, 63, 1024])
# ****************************************
# torch.Size([32, 57, 1024])
# ****************************************
# torch.Size([32, 49, 1024])
# ****************************************
# torch.Size([32, 52, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# epoch 1, iter 530, avg. loss 169.61, avg. ppl 265.51 cum. examples 16960, speed 11287.77 words/sec, time elapsed 50.23 sec
# torch.Size([32, 42, 1024])
# ****************************************
# torch.Size([32, 51, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 56, 1024])
# ****************************************
# torch.Size([32, 54, 1024])
# ****************************************
# torch.Size([32, 73, 1024])
# ****************************************
# torch.Size([32, 48, 1024])
# ****************************************
# torch.Size([32, 65, 1024])
# ****************************************
# torch.Size([32, 71, 1024])
# ****************************************
# torch.Size([32, 83, 1024])
# ****************************************
# torch.Size([32, 36, 1024])
# ****************************************
# epoch 1, iter 540, avg. loss 174.64, avg. ppl 284.15 cum. examples 17280, speed 10812.56 words/sec, time elapsed 51.14 sec
# torch.Size([32, 58, 1024])
# ****************************************
# torch.Size([32, 73, 1024])
# ****************************************
# torch.Size([32, 66, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 50, 1024])
# ****************************************
# torch.Size([32, 69, 1024])
# ****************************************
# torch.Size([32, 47, 1024])
# ****************************************
# torch.Size([32, 63, 1024])
# ****************************************
# torch.Size([32, 59, 1024])
# ****************************************
# torch.Size([32, 48, 1024])
# ****************************************
# torch.Size([32, 63, 1024])
# ****************************************
# epoch 1, iter 550, avg. loss 173.04, avg. ppl 271.19 cum. examples 17600, speed 10776.62 words/sec, time elapsed 52.06 sec
# torch.Size([32, 75, 1024])
# ****************************************
# torch.Size([32, 54, 1024])
# ****************************************
# torch.Size([32, 64, 1024])
# ****************************************
# torch.Size([32, 45, 1024])
# ****************************************
# torch.Size([32, 66, 1024])
# ****************************************
# torch.Size([32, 54, 1024])
# ****************************************
# torch.Size([32, 54, 1024])
# ****************************************
# torch.Size([32, 47, 1024])
# ****************************************
# torch.Size([32, 52, 1024])
# ****************************************
# epoch 1, iter 560, avg. loss 172.62, avg. ppl 274.31 cum. examples 17920, speed 10813.86 words/sec, time elapsed 52.97 sec
# torch.Size([32, 50, 1024])
# ****************************************
# torch.Size([32, 61, 1024])
# ****************************************
# torch.Size([32, 51, 1024])
# ****************************************
# torch.Size([32, 51, 1024])
# ****************************************
# torch.Size([32, 48, 1024])
# ****************************************
# torch.Size([32, 47, 1024])
# ****************************************
# torch.Size([32, 41, 1024])
# ****************************************
# torch.Size([32, 51, 1024])
# ****************************************
# torch.Size([32, 54, 1024])
# ****************************************
# epoch 1, iter 570, avg. loss 167.99, avg. ppl 264.90 cum. examples 18240, speed 11187.77 words/sec, time elapsed 53.83 sec
# torch.Size([32, 52, 1024])
# ****************************************
# torch.Size([32, 57, 1024])
# ****************************************
# torch.Size([32, 51, 1024])
# ****************************************
# torch.Size([32, 54, 1024])
# ****************************************
# torch.Size([32, 59, 1024])
# ****************************************
# torch.Size([32, 50, 1024])
# ****************************************
# torch.Size([32, 42, 1024])
# ****************************************
# torch.Size([32, 58, 1024])
# ****************************************
# torch.Size([32, 58, 1024])
# ****************************************
# torch.Size([32, 69, 1024])
# ****************************************
# torch.Size([32, 47, 1024])
# ****************************************
# torch.Size([32, 47, 1024])
# ****************************************
# epoch 1, iter 580, avg. loss 167.53, avg. ppl 259.40 cum. examples 18560, speed 11332.26 words/sec, time elapsed 54.68 sec
# torch.Size([32, 62, 1024])
# ****************************************
# torch.Size([32, 56, 1024])
# ****************************************
# torch.Size([32, 59, 1024])
# ****************************************
# torch.Size([32, 64, 1024])
# ****************************************
# torch.Size([32, 54, 1024])
# ****************************************
# torch.Size([32, 84, 1024])
# ****************************************
# torch.Size([32, 47, 1024])
# ****************************************
# torch.Size([32, 54, 1024])
# ****************************************
# epoch 1, iter 590, avg. loss 184.78, avg. ppl 272.12 cum. examples 18880, speed 11830.27 words/sec, time elapsed 55.57 sec
# torch.Size([32, 61, 1024])
# ****************************************
# torch.Size([32, 48, 1024])
# ****************************************
# torch.Size([32, 103, 1024])
# ****************************************
# torch.Size([32, 50, 1024])
# ****************************************
# torch.Size([32, 66, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 48, 1024])
# ...
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 73, 1024])
# ****************************************
# epoch 9, iter 23860, avg. loss 52.87, avg. ppl 5.64 cum. examples 27520, speed 10546.95 words/sec, time elapsed 2355.11 sec
# torch.Size([32, 70, 1024])
# ****************************************
# torch.Size([32, 54, 1024])
# ****************************************
# torch.Size([32, 49, 1024])
# ****************************************
# torch.Size([32, 62, 1024])
# ****************************************
# torch.Size([32, 49, 1024])
# ****************************************
# torch.Size([32, 64, 1024])
# ****************************************
# torch.Size([32, 50, 1024])
# ****************************************
# torch.Size([32, 57, 1024])
# ****************************************
# torch.Size([32, 52, 1024])
# ****************************************
# epoch 9, iter 23870, avg. loss 55.67, avg. ppl 5.68 cum. examples 27840, speed 10450.12 words/sec, time elapsed 2356.10 sec
# torch.Size([32, 55, 1024])
# ****************************************
# torch.Size([32, 44, 1024])
# ****************************************
# torch.Size([32, 69, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 65, 1024])
# ****************************************
# torch.Size([32, 67, 1024])
# ****************************************
# torch.Size([32, 68, 1024])
# ****************************************
# torch.Size([32, 35, 1024])
# ****************************************
# torch.Size([32, 48, 1024])
# ****************************************
# torch.Size([32, 42, 1024])
# ****************************************
# torch.Size([32, 84, 1024])
# ****************************************
# torch.Size([32, 66, 1024])
# ****************************************
# epoch 9, iter 23880, avg. loss 50.80, avg. ppl 5.49 cum. examples 28160, speed 10452.31 words/sec, time elapsed 2357.01 sec
# torch.Size([32, 51, 1024])
# ****************************************
# torch.Size([32, 47, 1024])
# ****************************************
# torch.Size([32, 52, 1024])
# ****************************************
# torch.Size([32, 46, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 64, 1024])
# ****************************************
# torch.Size([32, 48, 1024])
# ****************************************
# torch.Size([32, 54, 1024])
# ****************************************
# torch.Size([32, 78, 1024])
# ****************************************
# epoch 9, iter 23890, avg. loss 57.02, avg. ppl 5.73 cum. examples 28480, speed 10585.87 words/sec, time elapsed 2358.00 sec
# torch.Size([32, 64, 1024])
# ****************************************
# torch.Size([32, 47, 1024])
# ****************************************
# torch.Size([32, 48, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 101, 1024])
# ****************************************
# torch.Size([32, 55, 1024])
# ****************************************
# torch.Size([32, 73, 1024])
# ****************************************
# torch.Size([32, 60, 1024])
# ****************************************
# torch.Size([32, 63, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 49, 1024])
# ****************************************
# epoch 9, iter 23900, avg. loss 52.16, avg. ppl 5.28 cum. examples 28800, speed 10645.87 words/sec, time elapsed 2358.94 sec
# torch.Size([32, 59, 1024])
# ****************************************
# torch.Size([32, 50, 1024])
# ****************************************
# torch.Size([32, 61, 1024])
# ****************************************
# torch.Size([32, 62, 1024])
# ****************************************
# torch.Size([32, 85, 1024])
# ****************************************
# torch.Size([32, 57, 1024])
# ****************************************
# torch.Size([32, 67, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 45, 1024])
# ****************************************
# epoch 9, iter 23910, avg. loss 53.54, avg. ppl 5.64 cum. examples 29120, speed 10344.34 words/sec, time elapsed 2359.90 sec
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 45, 1024])
# ****************************************
# torch.Size([32, 65, 1024])
# ****************************************
# torch.Size([32, 57, 1024])
# ****************************************
# torch.Size([32, 66, 1024])
# ****************************************
# torch.Size([32, 73, 1024])
# ****************************************
# torch.Size([32, 42, 1024])
# ****************************************
# torch.Size([32, 51, 1024])
# ****************************************
# torch.Size([32, 110, 1024])
# ****************************************
# epoch 9, iter 23920, avg. loss 52.01, avg. ppl 5.42 cum. examples 29440, speed 10498.77 words/sec, time elapsed 2360.84 sec
# torch.Size([32, 44, 1024])
# ****************************************
# torch.Size([32, 50, 1024])
# ****************************************
# torch.Size([32, 45, 1024])
# ****************************************
# torch.Size([32, 60, 1024])
# ****************************************
# torch.Size([32, 51, 1024])
# ****************************************
# torch.Size([32, 44, 1024])
# ****************************************
# torch.Size([32, 62, 1024])
# ****************************************
# torch.Size([32, 68, 1024])
# ****************************************
# torch.Size([32, 51, 1024])
# ****************************************
# torch.Size([32, 59, 1024])
# ****************************************
# torch.Size([32, 45, 1024])
# ****************************************
# epoch 9, iter 23930, avg. loss 49.72, avg. ppl 5.27 cum. examples 29760, speed 11642.87 words/sec, time elapsed 2361.66 sec
# torch.Size([32, 56, 1024])
# ****************************************
# torch.Size([32, 45, 1024])
# ****************************************
# torch.Size([32, 50, 1024])
# ****************************************
# torch.Size([32, 63, 1024])
# ****************************************
# torch.Size([32, 51, 1024])
# ****************************************
# torch.Size([32, 65, 1024])
# ****************************************
# torch.Size([32, 47, 1024])
# ****************************************
# torch.Size([32, 52, 1024])
# ****************************************
# torch.Size([32, 57, 1024])
# ****************************************
# epoch 9, iter 23940, avg. loss 56.03, avg. ppl 6.00 cum. examples 30080, speed 10647.08 words/sec, time elapsed 2362.60 sec
# torch.Size([32, 51, 1024])
# ****************************************
# torch.Size([32, 61, 1024])
# ****************************************
# torch.Size([32, 43, 1024])
# ****************************************
# torch.Size([32, 55, 1024])
# ****************************************
# torch.Size([32, 48, 1024])
# ****************************************
# torch.Size([32, 51, 1024])
# ****************************************
# torch.Size([32, 66, 1024])
# ****************************************
# torch.Size([32, 66, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 54, 1024])
# ****************************************
# torch.Size([32, 74, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# epoch 9, iter 23950, avg. loss 53.83, avg. ppl 5.70 cum. examples 30400, speed 11127.58 words/sec, time elapsed 2363.49 sec
# torch.Size([32, 44, 1024])
# ****************************************
# torch.Size([32, 48, 1024])
# ****************************************
# torch.Size([32, 50, 1024])
# ****************************************
# torch.Size([32, 65, 1024])
# ****************************************
# torch.Size([32, 54, 1024])
# ****************************************
# torch.Size([32, 55, 1024])
# ****************************************
# torch.Size([32, 50, 1024])
# ****************************************
# torch.Size([32, 67, 1024])
# ****************************************
# epoch 9, iter 23960, avg. loss 59.19, avg. ppl 6.34 cum. examples 30720, speed 10393.38 words/sec, time elapsed 2364.47 sec
# torch.Size([32, 52, 1024])
# ****************************************
# torch.Size([32, 72, 1024])
# ****************************************
# torch.Size([32, 60, 1024])
# ****************************************
# torch.Size([32, 44, 1024])
# ****************************************
# torch.Size([32, 69, 1024])
# ****************************************
# torch.Size([32, 55, 1024])
# ****************************************
# torch.Size([32, 59, 1024])
# ****************************************
# torch.Size([32, 39, 1024])
# ****************************************
# torch.Size([32, 67, 1024])
# ****************************************
# torch.Size([32, 63, 1024])
# ****************************************
# torch.Size([32, 47, 1024])
# ****************************************
# epoch 9, iter 23970, avg. loss 51.57, avg. ppl 5.43 cum. examples 31040, speed 9961.39 words/sec, time elapsed 2365.45 sec
# torch.Size([32, 58, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 73, 1024])
# ****************************************
# torch.Size([32, 63, 1024])
# ****************************************
# torch.Size([32, 52, 1024])
# ****************************************
# torch.Size([32, 46, 1024])
# ****************************************
# torch.Size([32, 57, 1024])
# ****************************************
# torch.Size([32, 61, 1024])
# ****************************************
# torch.Size([32, 58, 1024])
# ****************************************
# epoch 9, iter 23980, avg. loss 53.83, avg. ppl 5.57 cum. examples 31360, speed 10317.84 words/sec, time elapsed 2366.43 sec
# torch.Size([32, 67, 1024])
# ****************************************
# torch.Size([32, 59, 1024])
# ****************************************
# torch.Size([32, 46, 1024])
# ****************************************
# torch.Size([32, 50, 1024])
# ****************************************
# torch.Size([32, 96, 1024])
# ****************************************
# torch.Size([32, 49, 1024])
# ****************************************
# torch.Size([32, 50, 1024])
# ****************************************
# torch.Size([32, 57, 1024])
# ****************************************
# torch.Size([32, 53, 1024])
# ****************************************
# torch.Size([32, 44, 1024])
# ****************************************
# torch.Size([32, 50, 1024])
# ****************************************
# epoch 9, iter 23990, avg. loss 55.94, avg. ppl 5.97 cum. examples 31680, speed 10767.28 words/sec, time elapsed 2367.36 sec
# torch.Size([32, 70, 1024])
# ****************************************
# torch.Size([32, 82, 1024])
# ****************************************
# torch.Size([32, 50, 1024])
# ****************************************
# torch.Size([32, 44, 1024])
# ****************************************
# torch.Size([32, 35, 1024])
# ****************************************
# torch.Size([32, 74, 1024])
# ****************************************
# torch.Size([32, 56, 1024])
# ****************************************
# torch.Size([32, 64, 1024])
# ****************************************
# torch.Size([32, 63, 1024])
# ****************************************
# torch.Size([128, 57, 1024])
# ****************************************
# epoch 9, iter 24000, avg. loss 51.99, avg. ppl 5.90 cum. examples 32000, speed 9559.20 words/sec, time elapsed 2368.34 sec
#
# [Validation] epoch 9, iter 24000, cum. loss 55.18, cum. ppl 5.89 cum. examples 32000
# begin validation ...
# torch.Size([128, 58, 1024])
# ****************************************
# torch.Size([128, 56, 1024])
# ****************************************
# torch.Size([128, 68, 1024])
# ****************************************
# torch.Size([128, 73, 1024])
# ****************************************
# torch.Size([128, 80, 1024])
# ****************************************
# torch.Size([128, 64, 1024])
# ****************************************
# torch.Size([128, 58, 1024])
# ****************************************
# torch.Size([128, 63, 1024])
# ****************************************
# torch.Size([128, 77, 1024])
# ****************************************
# torch.Size([128, 69, 1024])
# ****************************************
# torch.Size([128, 71, 1024])
# ****************************************
# torch.Size([128, 67, 1024])
# ****************************************
# torch.Size([128, 86, 1024])
# ****************************************
# torch.Size([128, 112, 1024])
# ****************************************
# torch.Size([128, 85, 1024])
# ****************************************
# torch.Size([128, 69, 1024])
# ****************************************
# torch.Size([128, 68, 1024])
# ****************************************
# torch.Size([128, 76, 1024])
# ****************************************
# torch.Size([128, 67, 1024])
# ****************************************
# torch.Size([128, 99, 1024])
# ****************************************
# torch.Size([128, 61, 1024])
# ****************************************
# torch.Size([128, 75, 1024])
# ****************************************
# torch.Size([128, 85, 1024])
# ****************************************
# torch.Size([128, 65, 1024])
# ****************************************
# torch.Size([128, 73, 1024])
# ****************************************
# torch.Size([128, 62, 1024])
# ****************************************
# torch.Size([128, 69, 1024])
# ****************************************
# torch.Size([128, 68, 1024])
# ****************************************
# torch.Size([128, 83, 1024])
# ****************************************
# torch.Size([128, 73, 1024])
# ****************************************
# torch.Size([128, 71, 1024])
# ****************************************
# torch.Size([128, 77, 1024])
# ****************************************
# torch.Size([128, 76, 1024])
# ****************************************
# torch.Size([128, 61, 1024])
# ****************************************
# torch.Size([128, 71, 1024])
# ****************************************
# torch.Size([128, 71, 1024])
# ****************************************
# torch.Size([128, 78, 1024])
# ****************************************
# torch.Size([128, 68, 1024])
# ****************************************
# torch.Size([128, 66, 1024])
# ****************************************
# torch.Size([128, 68, 1024])
# ****************************************
# torch.Size([128, 88, 1024])
# ****************************************
# torch.Size([128, 83, 1024])
# ****************************************
# torch.Size([128, 74, 1024])
# ****************************************
# torch.Size([128, 65, 1024])
# ****************************************
# torch.Size([128, 63, 1024])
# ****************************************
# torch.Size([128, 68, 1024])
# ****************************************
# torch.Size([128, 93, 1024])
# ****************************************
# torch.Size([128, 67, 1024])
# ****************************************
# torch.Size([128, 62, 1024])
# ****************************************
# torch.Size([128, 60, 1024])
# ****************************************
# torch.Size([128, 57, 1024])
# ****************************************
# torch.Size([128, 61, 1024])
# ****************************************
# torch.Size([128, 84, 1024])
# ****************************************
# torch.Size([128, 78, 1024])
# ****************************************
# torch.Size([128, 101, 1024])
# ****************************************
# torch.Size([128, 69, 1024])
# ****************************************
# torch.Size([128, 66, 1024])
# ****************************************
# torch.Size([128, 80, 1024])
# ****************************************
# torch.Size([128, 51, 1024])
# ****************************************
# torch.Size([128, 53, 1024])
# ****************************************
# torch.Size([128, 64, 1024])
# ****************************************
# torch.Size([125, 52, 1024])
# ****************************************
# [Validation] iter 24000, dev. ppl 13.508489469254815
# hit patience 1
# hit #5 trial
# Early stop!

# %% [markdown]
# # Part4:可视化

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import sys
from collections import namedtuple
from typing import Dict, List, Set, Tuple, Union

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.nn.utils
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence


# 1. 定义一个 *新的* Hypothesis，它包含 attention_weights 字段
Hypothesis = namedtuple('Hypothesis', ['value', 'score', 'attention_weights'])


class VisualizableNMT(NMT):
    """
    这是一个 NMT 的子类，专门用于推断和可视化。
    它重写了 step 和 beam_search 方法来捕捉注意力权重。
    你原来的 nmt_model.py 文件保持不变。
    """

    # 2. 重写 'step' 方法
    # (这是从 nmt_model.py 完整复制过来的，只修改了最后一行)
    def step(self, Ybar_t: torch.Tensor,
            dec_state: Tuple[torch.Tensor, torch.Tensor],
            enc_hiddens: torch.Tensor,
            enc_hiddens_proj: torch.Tensor,
            enc_masks: torch.Tensor) -> Tuple[Tuple, torch.Tensor, torch.Tensor]:
        """ Compute one forward step of the LSTM decoder, including the attention computation.
        """
        combined_output = None
        dec_state = self.decoder(Ybar_t, dec_state)
        dec_hidden, dec_cell = dec_state
        e_t = torch.squeeze(torch.bmm(enc_hiddens_proj, torch.unsqueeze(dec_hidden, dim=2)), dim=2)

        # Set e_t to -inf where enc_masks has 1 to ignore <pad> tokens
        if enc_masks is not None:
            e_t.data.masked_fill_(enc_masks.bool(), -float('inf'))

        alpha_t = F.softmax(e_t, dim=1) # (b, src_len)
        a_t = torch.squeeze(torch.bmm(torch.unsqueeze(alpha_t, 1), enc_hiddens), dim=1) # (b, 2h)
        U_t = torch.cat((dec_hidden, a_t), dim=1)
        V_t = self.combined_output_projection(U_t)
        O_t = self.dropout(self.activation(V_t))

        combined_output = O_t

        # 【修改点】返回 alpha_t (注意力权重) 而不是 e_t
        return dec_state, combined_output, alpha_t

    # 3. 重写 'beam_search' 方法
    # (这是我们之前讨论过的修改版，用于追踪注意力历史)
    def beam_search(self, src_sent: List[str], beam_size: int=5, max_decoding_time_step: int=70) -> List[Hypothesis]:
        """ Given a single source sentence, perform beam search, yielding translations in the target language.
        @returns hypotheses (List[Hypothesis]): a list of hypothesis, each hypothesis has three fields:
                value: List[str]: the decoded target sentence
                score: float: the log-likelihood of the target sentence
                attention_weights: torch.Tensor: a tensor of shape (tgt_len, src_len)
        """
        src_sents_var = self.vocab.src.to_input_tensor([src_sent], self.device)

        src_encodings, dec_init_vec = self.encode(src_sents_var, [len(src_sent)])
        src_encodings_att_linear = self.att_projection(src_encodings)

        h_tm1 = dec_init_vec
        att_tm1 = torch.zeros(1, self.hidden_size, device=self.device)

        eos_id = self.vocab.tgt['</s>']

        hypotheses = [['<s>']]
        hyp_scores = torch.zeros(len(hypotheses), dtype=torch.float, device=self.device)

        # 新增：用于追踪每个假设的注意力历史
        hyp_att_histories = [[]]

        completed_hypotheses = []

        t = 0
        while len(completed_hypotheses) < beam_size and t < max_decoding_time_step:
            t += 1
            hyp_num = len(hypotheses)

            exp_src_encodings = src_encodings.expand(hyp_num,
                                                     src_encodings.size(1),
                                                     src_encodings.size(2))

            exp_src_encodings_att_linear = src_encodings_att_linear.expand(hyp_num,
                                                                           src_encodings_att_linear.size(1),
                                                                           src_encodings_att_linear.size(2))

            y_tm1 = torch.tensor([self.vocab.tgt[hyp[-1]] for hyp in hypotheses], dtype=torch.long, device=self.device)
            y_t_embed = self.model_embeddings.target(y_tm1)

            x = torch.cat([y_t_embed, att_tm1], dim=-1)

            # 修改：接收 alpha_t
            (h_t, cell_t), att_t, alpha_t  = self.step(x, h_tm1,
                                                      exp_src_encodings, exp_src_encodings_att_linear, enc_masks=None)

            log_p_t = F.log_softmax(self.target_vocab_projection(att_t), dim=-1)

            live_hyp_num = beam_size - len(completed_hypotheses)
            contiuating_hyp_scores = (hyp_scores.unsqueeze(1).expand_as(log_p_t) + log_p_t).view(-1)
            top_cand_hyp_scores, top_cand_hyp_pos = torch.topk(contiuating_hyp_scores, k=live_hyp_num)

            prev_hyp_ids = top_cand_hyp_pos // len(self.vocab.tgt)
            hyp_word_ids = top_cand_hyp_pos % len(self.vocab.tgt)

            new_hypotheses = []
            live_hyp_ids = []
            new_hyp_scores = []
            new_hyp_att_histories = [] # 新增

            for prev_hyp_id, hyp_word_id, cand_new_hyp_score in zip(prev_hyp_ids, hyp_word_ids, top_cand_hyp_scores):
                prev_hyp_id = prev_hyp_id.item()
                hyp_word_id = hyp_word_id.item()
                cand_new_hyp_score = cand_new_hyp_score.item()

                hyp_word = self.vocab.tgt.id2word[hyp_word_id]
                new_hyp_sent = hypotheses[prev_hyp_id] + [hyp_word]

                # 新增：记录注意力历史
                prev_att_history = hyp_att_histories[prev_hyp_id]
                current_att_vector = alpha_t[prev_hyp_id]
                new_att_history = prev_att_history + [current_att_vector]

                if hyp_word == '</s>':
                    # 修改：使用我们新的 Hypothesis tuple
                    completed_hypotheses.append(Hypothesis(value=new_hyp_sent[1:-1],
                                                           score=cand_new_hyp_score,
                                                           attention_weights=torch.stack(new_att_history)))
                else:
                    new_hypotheses.append(new_hyp_sent)
                    live_hyp_ids.append(prev_hyp_id)
                    new_hyp_scores.append(cand_new_hyp_score)
                    new_hyp_att_histories.append(new_att_history) # 新增

            if len(completed_hypotheses) == beam_size:
                break

            live_hyp_ids = torch.tensor(live_hyp_ids, dtype=torch.long, device=self.device)
            h_tm1 = (h_t[live_hyp_ids], cell_t[live_hyp_ids])
            att_tm1 = att_t[live_hyp_ids]

            hypotheses = new_hypotheses
            hyp_scores = torch.tensor(new_hyp_scores, dtype=torch.float, device=self.device)
            # 累积所有decoder输出对所有encoder的注意力
            hyp_att_histories = new_hyp_att_histories # 新增

        if len(completed_hypotheses) == 0:
            # 修改：使用我们新的 Hypothesis tuple
            completed_hypotheses.append(Hypothesis(value=hypotheses[0][1:],
                                                   score=hyp_scores[0].item(),
                                                   attention_weights=torch.stack(hyp_att_histories[0])))

        completed_hypotheses.sort(key=lambda hyp: hyp.score, reverse=True)

        return completed_hypotheses

    # 4. 重写 'load' 静态方法
    @staticmethod
    def load(model_path: str):
        """
        加载模型文件。
        此方法被重写，以确保加载参数时创建的是 VisualizableNMT 实例。
        """
        params = torch.load(model_path, map_location=lambda storage, loc: storage, weights_only=False)
        args = params['args']
        if 'bidirectional' not in args:
            print("WARNING: 'bidirectional' key not found in saved args. Forcing True for decoding.", file=sys.stderr)
            args['bidirectional'] = True

        # 【修改点】创建 *当前类* (VisualizableNMT) 的实例，而不是 NMT
        model = VisualizableNMT(vocab=params['vocab'], **args)
        model.load_state_dict(params['state_dict'])

        return model

# %% [markdown]
# ## 单步推断

# %%
# !pip install sacrebleu
# Out:
# Requirement already satisfied: sacrebleu in /usr/local/lib/python3.12/dist-packages (2.5.1)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (3.2.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (2024.11.6)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (2.0.2)
# Requirement already satisfied: colorama in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (0.4.6)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (5.4.0)

# %%
def read_sent_zh(sent, source):
    """ Read a Chinese sentence, seperate the words using jieba, and generate tokens
    @param sent (str): path to file containing corpus
    @param source (str): "tgt" or "src" for selecting sp model
    """
    sp = spm.SentencePieceProcessor()
    sp.load('{}.model'.format(source))

    sent = " ".join(jieba.cut(sent, HMM=True))
    subword_tokens = sp.encode_as_pieces(sent)

    return subword_tokens

# %%
# --- 确保在文件顶部导入了这些 ---
import torch
import sys
from typing import Dict, List
import os
import sacrebleu
# ---

def decode_single_sentence(model_path: str, vocab_path: str, sentence: str, use_cuda: bool=True,reference_sentence: str = None,  beam_size_val: int = 10, max_steps: int = 70):


    # 加载模型
    print(f"load model from {model_path}", file=sys.stderr)
    model = VisualizableNMT.load(model_path)

    # 加载词汇表
    print(f"load vocab from {vocab_path}", file=sys.stderr)
    vocab = Vocab.load(vocab_path)
    model.vocab = vocab  # 确保模型实例有词汇表

    # 设置设备
    if use_cuda:
        model = model.to(torch.device("cuda:0"))
    model.eval() # 设为评估模式

    # 用训练过的分词模型处理推断的句子
    print("Tokenizing sentence using 'read_sent_zh'...", file=sys.stderr)
    src_tokens = read_sent_zh(sentence, source='src')

    print(f"Source (Tokens): {src_tokens}", file=sys.stderr)


    # 执行推断
    with torch.no_grad():
        hypotheses = model.beam_search(src_tokens,
                                     beam_size=beam_size_val,
                                     max_decoding_time_step=max_steps)

    # --- 6. 格式化输出 (来自原版 decode 的 with open 循环) ---
    if not hypotheses:
        print("Error: No hypotheses generated.", file=sys.stderr)
        return None

    top_hyp = hypotheses[0]

    # 从 (value, score, ...) 中提取 'value'
    hyp_sent = ""
    try:
        # 兼容 (value, score, attention_weights)
        raw_hyp_sent = ''.join(top_hyp.value)
        hyp_sent = raw_hyp_sent.replace(' ', ' ').replace('▁', ' ')
        hyp_sent = hyp_sent.strip()
    except AttributeError:
        # 兼容 (value, score)
        raw_hyp_sent = ''.join(top_hyp[0])
        hyp_sent = raw_hyp_sent.replace(' ', ' ')
        hyp_sent = hyp_sent.strip()

    if reference_sentence:
        # sacrebleu.sentence_bleu 需要一个 str (模型翻译)
        # 和一个 str 列表 (标准答案可以有多个)
        bleu = sacrebleu.sentence_bleu(hyp_sent, [reference_sentence])

        # .score 给出的是 0-100 的分数
        print(f"BLEU 分数 (对比参考): {bleu.score:.2f}")
    print("\n--- 翻译结果 ---")
    print(f"源句: {sentence}")
    print(f"译句: {hyp_sent}")
    print(f"得分 (LogProb): {top_hyp.score:.4f}")

    return hyp_sent

# %%
sentence="尽管信任度差距在近几年中有所缩小，但即使最近的衰退——这通常被归咎于欧盟所实施的紧缩和欧元区危机——也只是略微降低了欧洲议会对国家议会的优势。"
reference_text = "Although the trust gap has narrowed in recent years, even the recent recession — which is often blamed on EU-imposed austerity and the eurozone crisis — has only slightly reduced the European Parliament's advantage over national parliaments."
decode_single_sentence('model.bin','vocab_zh_en.json',sentence=sentence,reference_sentence=reference_text)
# Out:
# load model from model.bin
# WARNING: 'bidirectional' key not found in saved args. Forcing True for decoding.
# Loading vocabulary from vocab_zh_en.json...
# torch.Size([1, 42, 1024])
# ****************************************
# BLEU 分数 (对比参考): 37.37
#
# --- 翻译结果 ---
# 源句: 尽管信任度差距在近几年中有所缩小，但即使最近的衰退——这通常被归咎于欧盟所实施的紧缩和欧元区危机——也只是略微降低了欧洲议会对国家议会的优势。
# 译句: Although the trust gap has narrowed in recent years, even as the recent recession – the austerity and eurozone crisis imposed by the EU – was only slightly narrowly reduced by the European Parliament’s strength to national parliaments.
# 得分 (LogProb): -20.9996
# load vocab from vocab_zh_en.json
# Tokenizing sentence using 'read_sent_zh'...
# Source (Tokens): ['▁尽管', '▁信任度', '▁差距', '▁在', '▁近几年', '▁中', '▁有所', '▁缩小', '▁,', '▁但', '▁即使', '▁最近', '▁的', '▁衰退', '▁—', '▁—', '▁这', '▁通常', '▁被', '▁归咎于', '▁欧盟', '▁所', '▁实施', '▁的', '▁紧缩', '▁和', '▁欧元区', '▁危机', '▁—', '▁—', '▁也', '▁只是', '▁略微', '▁降低', '▁了', '▁欧洲议会', '▁对', '▁国家', '▁议会', '▁的', '▁优势', '▁。']
# 'Although the trust gap has narrowed in recent years, even as the recent recession – the austerity and eurozone crisis imposed by the EU – was only slightly narrowly reduced by the European Parliament’s strength to national parliaments.'

# %% [markdown]
# ## 可视化

# %%
# --- 导入可视化库 ---
import altair as alt
import pandas as pd
import sacrebleu

# 启用 Colab 的 Altair 渲染器
alt.renderers.enable('colab')

def visualize_attention(
        model_path: str,
        vocab_path: str,
        sentence: str,
        use_cuda: bool,
        reference_sentence: str = None,
        beam_size: int = 10,
        max_steps: int = 70
    ):
    """
    加载模型，对单个句子进行推断，并使用 Altair 可视化注意力。
    在 Colab 中，此函数将返回一个可显示的 chart 对象。
    """

    # --- 1. 加载模型 ---
    print(f"load model from {model_path}", file=sys.stderr)
    model = VisualizableNMT.load(model_path)

    # --- 2. 加载词汇表 ---
    print(f"load vocab from {vocab_path}", file=sys.stderr)
    vocab = Vocab.load(vocab_path)
    model.vocab = vocab

    # --- 3. 设置设备 ---
    if use_cuda:
        model = model.to(torch.device("cuda:0"))
    model.eval()

    # --- 4. 处理单句 (使用 read_sent_zh) ---
    print("Tokenizing sentence using 'read_sent_zh'...", file=sys.stderr)
    src_tokens = read_sent_zh(sentence, source='src')
    print(f"Source (Tokens): {src_tokens}", file=sys.stderr)

    # --- 5. 执行推断 ---
    with torch.no_grad():
        hypotheses = model.beam_search(src_tokens,
                                     beam_size=beam_size,
                                     max_decoding_time_step=max_steps)

    # --- 6. 提取数据 ---
    if not hypotheses:
        print("Error: No hypotheses generated.", file=sys.stderr)
        return None

    top_hyp = hypotheses[0]
    tgt_tokens = top_hyp.value
    # 得到全局注意力值
    attention_matrix = top_hyp.attention_weights.cpu().numpy()
    attention_matrix_clipped = attention_matrix[:, 1:-1] # 裁掉 <s> 和 </s>

    # --- 7. 打印翻译结果 (使用清理逻辑) ---
    raw_hyp_sent = ''.join(top_hyp.value)
    hyp_sent = raw_hyp_sent.replace(' ', ' ').replace('▁', ' ').strip()

    print("\n--- 翻译结果 ---")
    print(f"源句: {sentence}")
    print(f"译句: {hyp_sent}")
    print(f"得分 (LogProb): {top_hyp.score:.4f}")

    if reference_sentence:
        bleu = sacrebleu.sentence_bleu(hyp_sent, [reference_sentence])
        print(f"BLEU 分数 (对比参考): {bleu.score:.2f}")

    # --- 8. 准备 DataFrame 并创建 Altair 图表 ---
    try:
        tgt_len, src_len = attention_matrix_clipped.shape

        # 维度检查
        if len(tgt_tokens) != tgt_len:
            min_len = min(len(tgt_tokens), tgt_len)
            tgt_tokens = tgt_tokens[:min_len]
            attention_matrix_clipped = attention_matrix_clipped[:min_len, :]
            tgt_len = min_len

        if len(src_tokens) != src_len:
             min_len_src = min(len(src_tokens), src_len)
             src_tokens = src_tokens[:min_len_src]
             attention_matrix_clipped = attention_matrix_clipped[:, :min_len_src]
             src_len = min_len_src

        data = []
        for i in range(tgt_len):  # Y 轴 (目标句)
            for j in range(src_len):  # X 轴 (源句)
                data.append({
                    "target_token": tgt_tokens[i].replace('▁', ' '),
                    "source_token": src_tokens[j].replace('▁', ' '),
                    "attention": attention_matrix_clipped[i, j],
                    "target_index": i,  # 用于排序
                    "source_index": j,  # 用于排序
                })

        df = pd.DataFrame(data)

        x_axis = alt.X('source_token',
                       sort=alt.EncodingSortField(field="source_index", op="min", order='ascending'),
                       axis=alt.Axis(title="Source Sentence (源句)"))

        y_axis = alt.Y('target_token',
                       sort=alt.EncodingSortField(field="target_index", op="min", order='ascending'),
                       axis=alt.Axis(title="Generated Translation (目标句)"))

        color = alt.Color('attention',
                          scale=alt.Scale(range='heatmap'),
                          legend=alt.Legend(title="Attention Weight"))

        tooltip = [
            alt.Tooltip('source_token', title='Source'),
            alt.Tooltip('target_token', title='Target'),
            alt.Tooltip('attention', title='Weight', format=".4f")
        ]

        chart = alt.Chart(df).mark_rect().encode(
            x=x_axis,
            y=y_axis,
            color=color,
            tooltip=tooltip
        ).properties(
            title='Attention Heatmap (zh -> en)'
        ).interactive()

        print(f"\n✅ 图表生成成功！")

        # 【关键】返回图表对象
        return chart

    except Exception as e:
        print(f"\n使用 Altair 绘图时出错: {e}", file=sys.stderr)
        return None

print("✅ 'visualize_attention' 函数定义成功。")
# Out:
# ✅ 'visualize_attention' 函数定义成功。

# %%
MODEL_FILE = "model.bin"
VOCAB_FILE = "vocab_zh_en.json" # 或 'vocab.pt'

# 你想要翻译的中文句子
SENTENCE_TO_TRANSLATE = "尽管信任度差距在近几年中有所缩小，但即使最近的衰退——这通常被归咎于欧盟所实施的紧缩和欧元区危机——也只是略微降低了欧洲议会对国家议会的优势。"

# (可选) 提供一个标准答案来计算 BLEU
REFERENCE_TRANSLATION = "Although the trust gap has narrowed in recent years, even the recent recession -- which is often blamed on EU-imposed austerity and the eurozone crisis -- has only slightly reduced the European Parliament's advantage over national parliaments."
# REFERENCE_TRANSLATION = None  # 如果没有标准答案，请设为 None

# 自动检测 CUDA
USE_CUDA = torch.cuda.is_available()

if USE_CUDA:
    print("🚀 正在使用 GPU (CUDA) 运行...")
else:
    print("🐌 正在使用 CPU 运行...")

# --- 调用函数 ---
chart = visualize_attention(
    model_path=MODEL_FILE,
    vocab_path=VOCAB_FILE,
    sentence=SENTENCE_TO_TRANSLATE,
    use_cuda=USE_CUDA,
    reference_sentence=REFERENCE_TRANSLATION,
    beam_size=10,
    max_steps=100  # 增加了最大步数以防句子太长
)
# Out:
# 🚀 正在使用 GPU (CUDA) 运行...
# load model from model.bin
# WARNING: 'bidirectional' key not found in saved args. Forcing True for decoding.
# Loading vocabulary from vocab_zh_en.json...
# torch.Size([1, 42, 1024])
# ****************************************
#
# --- 翻译结果 ---
# 源句: 尽管信任度差距在近几年中有所缩小，但即使最近的衰退——这通常被归咎于欧盟所实施的紧缩和欧元区危机——也只是略微降低了欧洲议会对国家议会的优势。
# 译句: Although the trust gap has narrowed in recent years, even as the recent recession – the austerity and eurozone crisis imposed by the EU – was only slightly narrowly reduced by the European Parliament’s strength to national parliaments.
# 得分 (LogProb): -20.9996
# BLEU 分数 (对比参考): 37.37
#
# ✅ 图表生成成功！
# load vocab from vocab_zh_en.json
# Tokenizing sentence using 'read_sent_zh'...
# Source (Tokens): ['▁尽管', '▁信任度', '▁差距', '▁在', '▁近几年', '▁中', '▁有所', '▁缩小', '▁,', '▁但', '▁即使', '▁最近', '▁的', '▁衰退', '▁—', '▁—', '▁这', '▁通常', '▁被', '▁归咎于', '▁欧盟', '▁所', '▁实施', '▁的', '▁紧缩', '▁和', '▁欧元区', '▁危机', '▁—', '▁—', '▁也', '▁只是', '▁略微', '▁降低', '▁了', '▁欧洲议会', '▁对', '▁国家', '▁议会', '▁的', '▁优势', '▁。']

# %%
chart
# Out:
# alt.Chart(...)
